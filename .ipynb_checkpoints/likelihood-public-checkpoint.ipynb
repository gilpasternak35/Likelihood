# %% [markdown]
# # Likelihood
# ### open source data quality monitor
#
# Colin Jemmott
# 2020
#
# Have you ever found out an ETL job failed because a customer called?  You ever retrain a machine learning model in production just to find out the data changed out from under you?  Have a dashboard break because new data violated your assumptions?
#
# ### Approach
#
# Everything is probability (or, rather [surprise](https://en.wikipedia.org/wiki/Entropy_(information_theory)#Introduction)!).  Works on a two dataframes for now - you have to get the data.
#
# Batch job, you pass in training and test.
#
# Taxonomy of problems for initial launch:
# - New values in categorical - bootstrapping
# - Missing values - bootstrapping (Nan is just another category)
# - Outliers in counts (missing or spike) - prophet
#
# To Do:
#
# - Outliers in counts of groups - bootstrapping
# - Outliers in values - kernel density?
#
# Later:
# - Outliers in correlation between categories - assocation rules / Bayesian network / just conditional probability
# - Delayed data (I think we need a writtenAt timestamp)
# - Multi-table: check joins
# - PCA?  Other anomaly detection?
# - Multitenant
#
# ### Tips
#
# Some of the analysis assumes that the data is stationary (ergodic).  If that is a bad assumption it might make sense to trim history.  maxTrainingSizeMultiple controls that.
#
# ### To Do
#
# - Change out data for something public (SDPD?)
# - Write params to JSON
# - preprocessor on bootsrtapping for columns with tons of entries.  Also numerical columns?
# - Throw a warning or error if the testing sample is too small?

# %%
# Full Project imports
import pandas as pd
import math as mt
import dateutil
from datetime import datetime, timedelta
import requests as rd
import numpy as np
from sklearn import neighbors, decomposition
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import smtplib
import scipy.stats as st
import os
from datetime import datetime, timedelta
import Levenshtein as leven
from pandas.api.types import is_numeric_dtype
import copy

# %% [markdown]
# # Get data
#
# Not part of the actual product, but here for ease of testing.

# %%
N_days = 90
batchHours = 7*24 # this grabs the most recent chunk and looks for differences with the remainder


# parameters (will put into JSON config file later)
params = {"fName": "pd_calls_for_service_2020_datasd.csv", # local CSV file only right now
          "ts": "date_time", # Timestamp for when the event happened in the world
          "bootstrapResamples":1000, # should probably be 10k for better accuracy, but much worse speed
          "maxTrainingSizeMultiple":10, # if there is more than X times more training data, trim to most recent
          "maxCategories":100, # maximum number of categories in a column - if higher we skip
          "minCategoryCount":10, # don't report boostrap surprise if a category has lower count
         }

# %% [markdown]
# ## Load data, split into training and test

# %%
df = pd.read_csv("pd_calls_for_service_2020_datasd.csv")
if(df.shape[0] <= 1000):
    print("Warning: small data set might produce inaccurate results")
df['ts'] = df[params['ts']]
print(df)
#.apply(dateutil.parser.parse, ignoretz=True) # could speed this up for ISO8601 - currently slow.
df['ts'] =  pd.to_datetime(df['ts'], format='%Y%m%d %H:%M:%S')
maxTs = max(df['ts'])
#df = df.assign(date_time = df.get("date_time").apply(datetime.strptime, args = ("%d/%m/%Y %H:%M:%S")))
batchTs = maxTs - timedelta(hours = batchHours)
testDf = df[df['ts'] > batchTs]
trainDf = df[df['ts'] < batchTs]
# Out:
#         incident_num            date_time  day_of_week  \
# 0       E20010000001  2020-01-01 00:00:09            4
# 1       E20010000002  2020-01-01 00:00:20            4
# 2       E20010000003  2020-01-01 00:00:21            4
# 3       E20010000004  2020-01-01 00:00:32            4
# 4       E20010000005  2020-01-01 00:00:42            4
# 5                            0                 NaN            CLEVELAND
# 6                         4300                 NaN            MANZANITA
# 7                         3800                 NaN            DALBERGIA
# 8                         4000                 NaN                LOGAN
# 9                            0                   S                 37TH
# 10                        1200                 NaN   HOTEL CIRCLE SOUTH
# 11                        5600                 NaN       MISSION CENTER
# 12                        4900                 NaN           SANTA CRUZ
# 13                        7400                 NaN                HYATT
# 14                        3500                 NaN                 45TH
# 15                        2200                 NaN             EL CAJON
# 16                        7400                 NaN              SKYLINE
# 17                        3500                 NaN                LOGAN
# 18                        3600                 NaN               KNOXIE
# 19                       16200                 NaN      AVENIDA VENUSTO
# 20                        6700                 NaN             BROOKLYN
# 21                           0                   W                  ASH
# 22                         500                   S                 36TH
# 23                        4800                 NaN              ATLANTA
# 24                        2600                 NaN     CALLE TRES LOMAS
# 25                           0                 NaN                DAWNE
# 26                        1300                 NaN                RIGEL
# 27                         400                 NaN           AGUA VISTA
# 28                         700                 NaN              O'MEARA
# 29                       10700                 NaN    SAN DIEGO MISSION
# ...                        ...                 ...                  ...
# 132593                   10000                 NaN               FRIARS
# 132594                       0                 NaN           UNIVERSITY
# 132595                       0                 NaN                 14TH
# 132596                    5000                 NaN               GENEVA
# 132597                    4000                 NaN                 33RD
# 132598                    4700                 NaN               WILSON
# 132599                       0                 NaN                 50TH
# 132600                    1700                 NaN               KEARNY
# 132601                    3000                 NaN                 DOVE
# 132602                    2800                 NaN               FAMOSA
# 132603                    3600                 NaN           CLAIREMONT
# 132604                       0                 NaN           COMMERCIAL
# 132605                    5000                 NaN         NORTH HARBOR
# 132606                    1500                 NaN     WEST MISSION BAY
# 132607                    1300                 NaN                 05TH
# 132608                    2700                 NaN                 MAIN
# 132609                       0                 NaN            PALM (SB)
# 132610                    1200                 NaN                 09TH
# 132611                     200                 NaN           COTTONWOOD
# 132612                    3000                 NaN           CLAIREMONT
# 132613                    3500                 NaN        MURPHY CANYON
# 132614                    2500                 NaN              QUIVIRA
# 132615                    2900                 NaN               MIDWAY
# 132616                    8100                 NaN               BALBOA
# 132617                    5900                 NaN                 BARK
# 132618                       0                 NaN                 FINO
# 132619                    8300                 NaN              HURLBUT
# 132620                     700                 NaN                 33RD
# 132621                    5100                 NaN                ACUNA
# 132622                    3200                 NaN              HOLIDAY
#
#        address_sfx_primary  address_dir_intersecting  \
# 0                      AVE                       NaN
# 1                      AVE                       NaN
# 2                      AVE                       NaN
# 3                      AVE                       NaN
# 4                      BLV                       NaN
# 5                      NaN                       NaN
# 6                       DR                       NaN
# 7                       CT                       NaN
# 8                      AVE                       NaN
# 9                       ST                       NaN
# 10                     NaN                       NaN
# 11                      RD                       NaN
# 12                     AVE                       NaN
# 13                      ST                       NaN
# 14                      ST                       NaN
# 15                     BLV                       NaN
# 16                      DR                       NaN
# 17                     AVE                       NaN
# 18                      ST                       NaN
# 19                     NaN                       NaN
# 20                     AVE                       NaN
# 21                      ST                       NaN
# 22                      ST                       NaN
# 23                      DR                       NaN
# 24                     NaN                       NaN
# 25                      ST                       NaN
# 26                      ST                       NaN
# 27                     WAY                       NaN
# 28                      ST                       NaN
# 29                      RD                       NaN
# ...                    ...                       ...
# 132593                  RD                       NaN
# 132594                 AVE                       NaN
# 132595                  ST                       NaN
# 132596                 NaN                       NaN
# 132597                  ST                       NaN
# 132598                 AVE                       NaN
# 132599                  ST                       NaN
# 132600                 AVE                       NaN
# 132601                  ST                       NaN
# 132602                 BLV                       NaN
# 132603                  DR                       NaN
# 132604                  ST                       NaN
# 132605                  DR                       NaN
# 132606                  DR                       NaN
# 132607                 AVE                       NaN
# 132608                  ST                       NaN
# 132609                 AVE                       NaN
# 132610                 AVE                       NaN
# 132611                  RD                       NaN
# 132612                  DR                       NaN
# 132613                  RD                       NaN
# 132614                  CT                       NaN
# 132615                  DR                       NaN
# 132616                 AVE                       NaN
# 132617                  ST                       NaN
# 132618                  DR                       NaN
# 132619                  ST                       NaN
# 132620                  ST                       NaN
# 132621                  ST                       NaN
# 132622                  CT                       NaN
#
#        address_road_intersecting  address_sfx_intersecting call_type  \
# 0                            NaN                       NaN      11-8
# 1                            NaN                       NaN        FD
# 2                            NaN                       NaN       AU1
# 3                            NaN                       NaN        FD
# 4                            NaN                       NaN      415V
# 5                         UNIVER                       NaN        FD
# 6                            NaN                       NaN       AU1
# 7                            NaN                       NaN       AU1
# 8                            NaN                       NaN      11-6
# 9                           BETA                       NaN       AU1
# 10                           NaN                       NaN      415V
# 11                           NaN                       NaN      415V
# 12                           NaN                       NaN      1171
# 13                           NaN                       NaN       AU1
# 14                           NaN                       NaN      11-6
# 15                           NaN                       NaN       242
# 16                           NaN                       NaN       AU1
# 17                           NaN                       NaN       AU1
# 18                           NaN                       NaN      459A
# 19                           NaN                       NaN       AU1
# 20                           NaN                       NaN       AU1
# 21                  NORTH HARBOR                       NaN    10852C
# 22                           NaN                       NaN       AU1
# 23                           NaN                       NaN     459HP
# 24                           NaN                       NaN       AU1
# 25                        CONRAD                       NaN       AU1
# 26                           NaN                       NaN       AU1
# 27                           NaN                       NaN       AU1
# 28                           NaN                       NaN   11-6SPT
# 29                           NaN                       NaN      1087
# ...                          ...                       ...       ...
# 132593                       NaN                       NaN    MPSSTP
# 132594                 LOUISIANA                       NaN      5150
# 132595                    MARKET                       NaN        FD
# 132596                       NaN                       NaN         T
# 132597                       NaN                       NaN      5150
# 132598                       NaN                       NaN      1155
# 132599                UNIVERSITY                       NaN       415
# 132600                       NaN                       NaN         T
# 132601                       NaN                       NaN       AU2
# 132602                       NaN                       NaN      415N
# 132603                       NaN                       NaN         T
# 132604                       NaN                       NaN    SELENF
# 132605                       NaN                       NaN       415
# 132606                       NaN                       NaN      1151
# 132607                       NaN                       NaN     459HP
# 132608                       NaN                       NaN    MPSSTP
# 132609         INTERSTATE 805 SB                       NaN        CW
# 132610                       NaN                       NaN      459R
# 132611                       NaN                       NaN    SELENF
# 132612                       NaN                       NaN         T
# 132613                       NaN                       NaN    SELENF
# 132614                       NaN                       NaN    SELENF
# 132615                       NaN                       NaN    1140OD
# 132616                       NaN                       NaN       415
# 132617                       NaN                       NaN      11-7
#
# [132623 rows x 15 columns]

# %%
trainDf.keys()
# Out:
# Index(['incident_num', 'date_time', 'day_of_week', 'address_number_primary',
#        'address_dir_primary', 'address_road_primary', 'address_sfx_primary',
#        'address_dir_intersecting', 'address_road_intersecting',
#        'address_sfx_intersecting', 'call_type', 'disposition', 'beat',
#        'priority', 'ts'],
#       dtype='object')

# %%
max(trainDf['ts'])
# Out:
# Timestamp('2020-04-07 23:49:55')

# %%
# Helpers and Math
def pValue(data, threshold):
    p_larger = sum(np.array(data) >= threshold) / len(data)
    p_smaller = sum(np.array(data) <= threshold) / len(data)
    p = min(p_larger, p_smaller)

    # only use gaussian p-value when there is variation, but bootsrap p = 0
    stdev = np.std(data)
    if stdev == 0 or p != 0:
        p_gauss = p
    else:
        p_gauss = scipy.stats.norm(np.mean(result['bootstrap_counts']), stdev).cdf(result['count'])
        p_gauss = min(p_gauss,1-p_gauss)
    return p_gauss

def trimTraining(trainDf, params):

    # trim to most recent
    trainDf = trainDf.sort_values(params['ts'], ascending =False)
    trainDfTrimmed = trainDf[:params['maxTrainingSizeMultiple']*len(testDf)]
    
    return trainDfTrimmed

# %%
# get all of the string columns
columnNames = []
for columnName in testDf.keys():
    if (type (testDf[columnName].iloc[0])) == str:
        columnNames.append(columnName)
print(columnNames)
bootstrapDf = trimTraining(trainDf, params)
        
# set up dict, add counts
results = {}
for columnName in columnNames:
    # if it isn't a string column, reject it
    if type(testDf[columnName].iloc[0]) != str:
        continue
    categories = (bootstrapDf[columnName].append(testDf[columnName])).unique()
    if len(categories) > params['maxCategories']:
        continue
    
    results[columnName] = {}
    testCounts = testDf[columnName].value_counts(dropna = False)
    for i in np.arange(1,len(categories) -1):
        if(pd.isna(categories[i])):
            categories = np.delete(categories, i)  
    for category in categories:
        results[columnName][category] = {'bootstrap_counts':[],
                                        'count':testCounts.get(category,0)}
# resample, add boostrap counts
for ii in range(params['bootstrapResamples']):
    # Draw random sample from training
    sampleDf = bootstrapDf.sample(len(testDf), replace=True)
    for columnName in results.keys():
        # count by category
        trainCounts = sampleDf[columnName].value_counts(dropna = False)
        # put results in dict
        for category in results[columnName].keys():
            boostrapCount = trainCounts.get(category,0)
            results[columnName][category]['bootstrap_counts'].append(boostrapCount)
              
# convert to records, add p-values
bootstrap_results = []
for columnName in results.keys():
    for category in results[columnName].keys():
        result = results[columnName][category]
        
        estimatedCount = int(np.round(np.mean(result['bootstrap_counts'])))
        # don't report entries with very low predicted and actual counts
        if estimatedCount < params['minCategoryCount'] and result['count'] < params['minCategoryCount']:
            continue
        
        p = pValue(result['bootstrap_counts'],result['count'])
        categoryName = category
        if not category:
            categoryName = "NULL"
        
        bootstrap_results.append({"column":columnName,
                           "category":categoryName,
                           "count":result['count'],
                           "p": p,
                           "estimated_count":estimatedCount,
                           })
if(np.count_nonzero(p)>0):
    resultsDf = pd.DataFrame.from_records(bootstrap_results).sort_values('p')
    resultsDf['surprise'] = -np.log2(resultsDf['p'])
# Out:
# ['incident_num', 'date_time', 'address_road_primary', 'address_sfx_primary', 'call_type', 'disposition']
# /Users/gilpasternak/opt/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:63: RuntimeWarning: divide by zero encountered in log2

# %%
resultsDf.head(70)
# Out:
#    category               column  count  estimated_count             p  \
# 17        K          disposition   6425             5571  0.000000e+00
# 23      CAN          disposition    638              878  5.203056e-17
# 20        A          disposition    360              484  8.326116e-10
# 21        R          disposition    723              876  4.627580e-08
# 19        W          disposition    462              584  1.017556e-07
# 18        O          disposition   1759             1958  1.764165e-07
# 2        DR  address_sfx_primary   1242             1155  1.000000e-03
# 15       LN  address_sfx_primary     68               87  1.800000e-02
# 22      DUP          disposition    175              152  2.100000e-02
# 25        X          disposition     18               28  3.300000e-02
# 7        CT  address_sfx_primary    144              167  3.500000e-02
# 9       PLZ  address_sfx_primary     15               22  6.400000e-02
# 11      PKY  address_sfx_primary     66               77  1.200000e-01
# 12      CIR  address_sfx_primary     13               19  1.240000e-01
# 13      WAL  address_sfx_primary     11                8  1.530000e-01
# 6       HWY  address_sfx_primary     34               41  1.570000e-01
# 16      TRL  address_sfx_primary     11                8  1.660000e-01
# 24        U          disposition    220              235  1.700000e-01
# 0        ST  address_sfx_primary   3299             3341  1.850000e-01
# 26        S          disposition     40               35  2.220000e-01
# 14      TER  address_sfx_primary     19               23  2.500000e-01
# 3       WAY  address_sfx_primary    230              240  2.760000e-01
# 10      MAL  address_sfx_primary     26               23  2.870000e-01
# 5       AVE  address_sfx_primary   2629             2606  3.170000e-01
# 4        RD  address_sfx_primary    941              952  3.710000e-01
# 1       BLV  address_sfx_primary   1069             1058  3.830000e-01
# 8        PL  address_sfx_primary    136              136  5.020000e-01
#
#      surprise
# 17        inf
# 23  54.093418
# 20  30.161637
# 21  24.365167
# 19  23.228388
# 18  22.434511
# 2    9.965784
# 15   5.795859
# 22   5.573467
# 25   4.921390
# 7    4.836501
# 9    3.965784
# 11   3.058894
# 12   3.011588
# 13   2.708396
# 6    2.671164
# 16   2.590745
# 24   2.556393
# 0    2.434403
# 26   2.171368
# 14   2.000000
# 3    1.857260
# 10   1.800877
# 5    1.657445
# 4    1.430509
# 1    1.384584
# 8    0.994241

# %% [markdown]
# # Timeseries forecast (prophet)
#
# Installing prophet is a major pain, especially on Windows.  Details: https://facebook.github.io/prophet/docs/installation.html
#
# Following the lead from Seismic interns: https://medium.com/seismic-data-science/anomaly-detection-using-prophet-a5dcea2c5473
#
# Decided to go hourly, but could change to day with a few tweaks.

# %%
from fbprophet import Prophet
# Out:
# ERROR:fbprophet:Importing plotly failed. Interactive plots will not work.

# %%
def truncateTs(ts):
    return ts.replace(minute=0, second=0,  microsecond=0)

# %%
truncatedData = trainDf['ts'].apply(truncateTs)

# Groups data by value counts and returns a table with corresponding y values according to 
def group_and_build_time_table(truncatedData):
    groupedCounts = truncatedData.value_counts()
    prophetDf = pd.DataFrame({'ds':groupedCounts.index,'y':np.log10(groupedCounts.values)})
    return prophetDf
prophetDf = group_and_build(truncatedData)
prophetDf
# Out:
#                       ds         y
# 0    2020-01-01 00:00:00  2.184691
# 1    2020-04-06 09:00:00  2.143015
    # Takes in trained model and predicts the future
    # find number of hours to preduct: ceil of hours in testDf
    testDf = testDf.assign(ts = testDf.get(timestamp))
    
    #If a column is string, convert to date/time
    if(testDf.applymap(type).eq(str).any()['ts']):
        testDf['ts'] = pd.to_datetime(testDf['ts'])
    
    timeDelta = max(testDf['ts']) -min(testDf['ts'])
    hours = int(timeDelta.days*24 + timeDelta.seconds/(60*60))+1
    future = m.make_future_dataframe(periods = hours, freq = 'H')
    forecast = m.predict(future)
    return forecast, testDf
forecast, testDf = predict_future(testDf)
forecast
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /Users/gilpasternak/opt/miniconda3/lib/python3.7/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
#                       ds     trend  yhat_lower  yhat_upper  trend_lower  \
# 0    2020-01-01 00:00:00  1.825886    1.462547    1.868200     1.825886
# 1    2020-01-01 01:00:00  1.825657    1.388260    1.766807     1.825657
# 2    2020-01-01 02:00:00  1.825427    1.253388    1.632786     1.825427
# 3    2020-01-01 03:00:00  1.825198    1.157084    1.541210     1.825198
# 4    2020-01-01 04:00:00  1.824968    1.155254    1.531888     1.824968
# 5    2020-01-01 05:00:00  1.824738    1.264388    1.639404     1.824738
# 6    2020-01-01 06:00:00  1.824509    1.405524    1.803681     1.824509
# 7    2020-01-01 07:00:00  1.824279    1.606542    1.990587     1.824279
# 8    2020-01-01 08:00:00  1.824050    1.710438    2.083419     1.824050
# 9    2020-01-01 09:00:00  1.823820    1.724190    2.120984     1.823820
# 10   2020-01-01 10:00:00  1.823590    1.710669    2.085051     1.823590
# 11   2020-01-01 11:00:00  1.823361    1.682961    2.069946     1.823361
# 12   2020-01-01 12:00:00  1.823131    1.667973    2.043705     1.823131
# 13   2020-01-01 13:00:00  1.822902    1.694865    2.074080     1.822902
# 14   2020-01-01 14:00:00  1.822672    1.723553    2.082801     1.822672
# 15   2020-01-01 15:00:00  1.822443    1.712649    2.090456     1.822443
# 16   2020-01-01 16:00:00  1.822213    1.683282    2.063902     1.822213
# 17   2020-01-01 17:00:00  1.821983    1.655034    2.026828     1.821983
# 18   2020-01-01 18:00:00  1.821754    1.608532    1.992959     1.821754
# 19   2020-01-01 19:00:00  1.821524    1.602930    1.967097     1.821524
# 20   2020-01-01 20:00:00  1.821295    1.600312    1.969781     1.821295
# 21   2020-01-01 21:00:00  1.821065    1.572728    1.968843     1.821065
# 22   2020-01-01 22:00:00  1.820835    1.579869    1.950516     1.820835
# 23   2020-01-01 23:00:00  1.820606    1.564396    1.938342     1.820606
# 24   2020-01-02 00:00:00  1.820376    1.630048    1.991105     1.820376
# 25   2020-01-02 01:00:00  1.820147    1.528274    1.886787     1.820147
# 26   2020-01-02 02:00:00  1.819917    1.406844    1.783411     1.819917
# 27   2020-01-02 03:00:00  1.819688    1.301416    1.679953     1.819688
# 28   2020-01-02 04:00:00  1.819458    1.273045    1.684110     1.819458
# 29   2020-01-02 05:00:00  1.819228    1.388453    1.755844     1.819228
# ...                  ...       ...         ...         ...          ...
# 1988 2020-04-13 18:00:00  1.776760    1.592483    1.960686     1.769971
# 1989 2020-04-13 19:00:00  1.776764    1.574958    1.947866     1.769888
# 19                           0.0                         0.0  1.788820
# 20                           0.0                         0.0  1.778024
# 21                           0.0                         0.0  1.772190
# 22                           0.0                         0.0  1.767495
# 23                           0.0                         0.0  1.750572
# 24                           0.0                         0.0  1.816417
# 25                           0.0                         0.0  1.719454
# 26                           0.0                         0.0  1.594577
# 27                           0.0                         0.0  1.493725
# 28                           0.0                         0.0  1.475743
# 29                           0.0                         0.0  1.565524
# ...                          ...                         ...       ...
# 1988                         0.0                         0.0  1.775243
# 1989                         0.0                         0.0  1.756764
# 1990                         0.0                         0.0  1.745595
# 1991                         0.0                         0.0  1.739805
# 1992                         0.0                         0.0  1.735569
# 1993                         0.0                         0.0  1.719517
# 1994                         0.0                         0.0  1.670055
# 1995                         0.0                         0.0  1.574761
# 1996                         0.0                         0.0  1.451934
# 1997                         0.0                         0.0  1.353495
# 1998                         0.0                         0.0  1.338271
# 1999                         0.0                         0.0  1.431132
# 2000                         0.0                         0.0  1.600180
# 2001                         0.0                         0.0  1.773241
# 2002                         0.0                         0.0  1.883621
# 2003                         0.0                         0.0  1.910577
# 2004                         0.0                         0.0  1.884287
# 2005                         0.0                         0.0  1.854775
# 2006                         0.0                         0.0  1.852772
# 2007                         0.0                         0.0  1.873554
# 2008                         0.0                         0.0  1.891678
# 2009                         0.0                         0.0  1.887976
# 2010                         0.0                         0.0  1.863810
# 2011                         0.0                         0.0  1.834121
# 2012                         0.0                         0.0  1.811574
# 2013                         0.0                         0.0  1.798902
# 2014                         0.0                         0.0  1.793424
# 2015                         0.0                         0.0  1.793153
# 2016                         0.0                         0.0  1.794212
# 2017                         0.0                         0.0  1.783179
#
# [2018 rows x 55 columns]

# %%
# group the test data
truncatedData = testDf['ts'].apply(truncateTs)

# Takes in truncated test data (column), spits out out the prophet results
def find_surprise(truncatedData, forecast):
    groupedCounts = truncatedData.value_counts()

    prophetTestDf = pd.DataFrame({'ds':groupedCounts.index,
                                  'y':np.log10(groupedCounts.values),
                                  'y_linear':groupedCounts.values})

    # find p-value
    prophet_results = []

    for ii in range(len(prophetTestDf)):
        ts = prophetTestDf['ds'][ii]
        fcstExample = fcst[fcst['ds'] == ts]
        mean = fcstExample['yhat'].iloc[0]
        stdev = (fcstExample['yhat_upper'].iloc[0] - fcstExample['yhat_lower'].iloc[0])/2
        p = scipy.stats.norm(mean, stdev).cdf(prophetTestDf['y'][ii])
        p = min(p,1-p)

        prophet_results.append({"column":"Forecast",
                           "category":str(ts),
                           "count":prophetTestDf['y_linear'][ii],
                           "p": p,
                           "estimated_count":int(np.round(np.power(10,mean))),
                           })

    prophetResultsDf = pd.DataFrame.from_records(prophet_results).sort_values('p')
    prophetResultsDf['surprise'] = -np.log2(prophetResultsDf['p'])
    return prophetResultsDf
find_surprise(truncatedData, forecast)
# Out:
#                 category    column  count  estimated_count             p  \
# 168  2020-04-07 23:00:00  Forecast      1               61  6.174456e-22
# 158  2020-04-14 23:00:00  Forecast     22               61  8.033441e-03
# 143  2020-04-12 22:00:00  Forecast     33               59  8.306008e-02
# 80   2020-04-14 06:00:00  Forecast     71               40  9.825371e-02
# 61   2020-04-13 14:00:00  Forecast     77               76  4.837640e-01
# 138  2020-04-09 02:00:00  Forecast     35               36  4.855131e-01
# 21   2020-04-09 10:00:00  Forecast     92               91  4.870198e-01
# 35   2020-04-11 13:00:00  Forecast     84               83  4.886550e-01
# 155  2020-04-13 03:00:00  Forecast     24               24  4.901577e-01
# 94   2020-04-10 23:00:00  Forecast     65               66  4.901720e-01
# 32   2020-04-08 12:00:00  Forecast     86               87  4.910014e-01
# 40   2020-04-11 12:00:00  Forecast     81               80  4.912077e-01
# 74   2020-04-08 19:00:00  Forecast     72               72  4.940075e-01
# 111  2020-04-13 20:00:00  Forecast     56               56  4.948794e-01
# 95   2020-04-14 18:00:00  Forecast     65               65  4.973048e-01
#
#       surprise
# 168  70.456106
# 158   6.959766
# 143   3.589701
# 80    3.347344
# 151   3.270977
# 81    3.173162
# 127   3.127539
# 167   3.115971
# 142   3.003229
# 136   2.957918
# 107   2.955761
# 70    2.545437
# 26    2.503391
# 115   2.492951
# 106   2.458338
# 166   2.447617
# 18    2.416792
# 157   2.363229
# 120   2.360389
# 108   2.341883
# 125   2.338900
# 0     2.338500
# 130   2.312757
# 144   2.261017
# 128   2.255949
# 88    2.254810
# 91    2.237755
# 146   2.229016
# 8     2.198904
# 9     2.171017
# ..         ...
# 46    1.132302
# 66    1.129171
# 33    1.126494
# 112   1.122862
# 24    1.114638
# 109   1.108598
# 22    1.086862
# 71    1.086438
# 89    1.083436
# 77    1.083045
# 54    1.082495
# 13    1.075298
# 92    1.072412
# 122   1.070826
# 135   1.064822
# 15    1.063161
# 78    1.059680
# 49    1.056817
# 44    1.047848
# 61    1.047625
# 138   1.042418
# 21    1.037948
# 35    1.033112
# 155   1.028682
# 94    1.028640
# 32    1.026201
# 40    1.025595
# 74    1.017395
# 111   1.014851
# 95    1.007798
#
# [169 rows x 6 columns]

# %%
# Takes in a model that has been trained on country, plots graphs for visualization
def visualize(m):
    # plotting for debug only
    fig = m.plot(fcst)
    fig = m.plot_components(fcst)
visualize(m)

# %% [markdown]
# # Kernel Density Implementation Below

# %%
#obtaining user input
#https://www.nbastuffer.com/2019-2020-nba-team-stats/
def inp(default = 1, default2 = "https://www.nbastuffer.com/2019-2020-nba-team-stats/"):
    if(default2 != "https://www.nbastuffer.com/2019-2020-nba-team-stats/"):
        nam = input()
    else:
        nam = default2
    frame = pd.read_html(nam)
    first_table = frame[default]
    return first_table
first_table = inp(1,"input")
# Out:
# https://www.nbastuffer.com/2019-2020-nba-team-stats/

# %%
first_table
# Out:
#     RANK           TEAM  CONF   DIVISION  GP  \
# 0    NaN        Atlanta  East  Southeast   5
# 1    NaN         Boston  East   Atlantic   5
# 2    NaN       Brooklyn  East   Atlantic   5
# 3    NaN      Charlotte  East  Southeast   5
# 4    NaN        Chicago  East    Central   5
# 5    NaN      Cleveland  East    Central   5
# 6    NaN         Dallas  West  Southwest   5
# 7    NaN         Denver  West  Northwest   5
# 8    NaN        Detroit  East    Central   5
# 9    NaN   Golden State  West    Pacific   5
# 10   NaN        Houston  West  Southwest   5
# 11   NaN        Indiana  East    Central   5
# 12   NaN    LA Clippers  West    Pacific   5
# 13   NaN      LA Lakers  West    Pacific   5
# 14   NaN        Memphis  West  Southwest   5
# 15   NaN          Miami  East  Southeast   5
# 16   NaN      Milwaukee  East    Central   5
# 17   NaN      Minnesota  West  Northwest   5
# 18   NaN    New Orleans  West  Southwest   5
# 19   NaN       New York  East   Atlantic   5
# 20   NaN  Oklahoma City  West  Northwest   5
# 21   NaN        Orlando  East  Southeast   5
# 22   NaN   Philadelphia  East   Atlantic   5
# 23   NaN        Phoenix  West    Pacific   5
# 24   NaN       Portland  West  Northwest   5
# 25   NaN     Sacramento  West    Pacific   5
# 26   NaN    San Antonio  West  Southwest   5
# 27   NaN        Toronto  East   Atlantic   5
# 28   NaN           Utah  West  Northwest   5
# 29   NaN     Washington  East  Southeast   5
#
#     PTS/GMPoints Per GameAverage points per game  \
# 0                                          115.0
# 1                                          108.8
# 2                                          112.2
# 3                                          114.0
# 4                                          106.8
# 5                                          111.6
# 6                                          115.8
# 7                                          104.4
# 8                                          100.4
# 9                                          112.8
# 10                                         110.0
# 11                                         109.4
# 12                                         119.8
# 13                                         113.8
# 14                                         114.8
# 15                                         104.6
# 16                                         107.4
# 17                                         118.0
# 18                                         120.2
# 19                                         110.8
# 20                                         105.0
# 21                                         119.6
# 22                                         120.0
# 23                                         117.0
# 24                                         120.8
# 25                                         116.6
# 26                                         116.6
# 27                                         116.2
# 28                                         108.0
# 29                                         111.8
#
#     aPTS/GMPoints Allowed Per GameAverage points allowed per game  \
# 0                                               127.4
# 1                                               110.0
# 2                                               113.4
# 3                                               111.6
# 4                                               108.6
# 5                                               115.4
# 6                                               109.4
# 7                                               108.0
# 8                                               110.2
# 9                                               118.0
# 10                                              118.0
# 11                                              111.0
# 12                                              109.6
# 13                                              106.2
# 14                                              101.8
# 15                                              102.0
# 16                                              113.4
# 17                                              122.2
# 18                                              119.8
# 19                                              115.0
# 20                                              111.2
# 21                                              117.0
# 22                                              117.6
# 23                                              121.4
# 24                                              113.2
# 25                                              116.0
# 26                                              119.8
# 27                                              113.0
# 28                                              103.4
# 29                                              117.0
#
#     PTS DIFFPoints Differential{(Total Points Scored) - (Total Points Allowed)}/ (Games Played)  \
# 0                                               -12.4
# 1                                                -1.2
# 2                                                -1.2
# 3                                                 2.4
# 4                                                -1.8
# 5                                                -3.8
# 6                                                 6.4
# 7                                                -3.6
# 8                                                -9.8
# 9                                                -5.2
# 10                                               -8.0
# 11                                               -1.6
# 12                                               10.2
# 13                                                7.6
# 14                                               13.0
# 15                                                2.6
# 16                                               -6.0
# 17                                               -4.2
# 18                                                0.4
# 19                                               -4.2
# 20                                               -6.2
# 21                                                2.6
# 22                                                2.4
# 23                                               -4.4
# 24                                                7.6
# 25                                                0.6
# 26                                               -3.2
# 27                                                3.2
# 28                                                4.6
# 29                                               -5.2
#
#     PACEPaceEstimate of Possessions Per 48 Minutes  \
# 0                                            100.0
# 1                                             97.7
# 2                                            100.3
# 3                                             90.1
# 4                                             99.6
# 5                                             96.5
# 6                                            100.5
# 7                                             96.4
# 8                                             94.3
# 9                                             97.8
# 10                                           101.5
# 11                                           100.5
# 12                                           100.0
# 13                                           101.9
# 14                                           100.6
# 15                                            95.7
# 16                                           105.2
# 17                                           105.3
# 18                                           107.4
# 19                                            98.1
# 20                                            99.9
# 21                                           100.1
# 22                                            96.1
# 23                                           101.2
# 24                                            99.0
# 25                                            99.5
# 26                                            99.5
# 27                                           101.1
# 28                                            93.6
# 29                                           100.5
#
#     OEFFOffensive EfficiencyPoints scored per 100 possessions.  ...  \
# 0                                               108.2           ...
# 1                                               109.1           ...
# 2                                               108.9           ...
# 3                                               121.3           ...
# 4                                               107.3           ...
# 5                                               113.0           ...
# 6                                               112.9           ...
# 7                                               108.6           ...
# 8                                               106.5           ...
# 9                                               115.8           ...
# 10                                              108.4           ...
# 11                                              109.3           ...
# 12                                              120.0           ...
# 13                                              112.0           ...
# 14                                              114.1           ...
# 15                                              109.5           ...
# 16                                              102.0           ...
# 17                                              112.4           ...
# 18                                              109.7           ...
# 19                                              110.1           ...
# 20                                              105.6           ...
# 21                                              119.5           ...
# 22                                              124.8           ...
# 23                                              115.5           ...
# 24                                              122.0           ...
# 25                                              117.1           ...
# 26                                              114.8           ...
# 27                                              114.8           ...
# 28                                              115.3           ...
# 29                                              110.9           ...
#
#     SARSchedule Adjusted RatingAn evaluation of teams based on efficiency differential and strength of schedule  \
# 0                                              -15.89
# 1                                               -1.50
# 2                                               -0.61
# 3                                                3.67
# 4                                               -3.00
# 5                                               -4.01
# 6                                                5.38
# 7                                               -5.45
# 8                                               -9.17
# 9                                               -4.65
# 10                                             -10.37
# 11                                               3.33
# 12                                              10.72
# 13                                               9.37
# 14                                              11.07
# 15                                               2.34
# 16                                              -0.96
# 17                                              -4.36
# 18                                               0.14
# 19                                              -5.28
# 20                                              -1.94
# 21                                               3.98
# 22                                               3.00
# 23                                              -4.58
# 24                                               5.05
# 25                                              -1.62
# 26                                              -3.95
# 27                                               3.27
# 28                                               4.60
# 29                                              -9.81
#
#     CONSConsistency RatingConsistency based on game-by-game efficiency differential variation. The higher the team has a consistency rating, the more unpredictable it is.  \
# 0                                                16.2
# 1                                                 5.9
# 2                                                22.7
# 3                                                 7.7
# 4                                                 5.3
# 5                                                 6.8
# 6                                                14.3
# 7                                                12.9
# 8                                                 5.5
# 9                                                16.2
# 10                                               10.0
# 11                                                9.8
# 12                                               12.7
# 13                                                5.8
# 14                                               28.3
# 15                                               11.9
# 16                                               13.6
# 17                                                9.4
# 18                                                7.9
# 19                                               13.9
# 20                                               25.7
# 21                                               16.7
# 22                                               14.7
# 23                                               13.0
# 24                                               17.3
# 25                                               11.7
# 26                                               10.1
# 27                                               10.1
# 28                                                8.8
# 29                                               11.8
#
#     A4FAdjusted Four FactorsCalculated by applying weights to the differentials of offensive and defensive four factors. A4F explains the specified proportion of variability in wins.  \
# 0                                              -0.047
# 1                                              -0.026
# 2                                              -0.006
# 3                                              -0.004
# 4                                              -0.042
# 5                                              -0.015
# 6                                              -0.005
# 7                                              -0.017
# 8                                              -0.033
# 9                                              -0.006
# 10                                             -0.041
# 11                                              0.019
# 12                                              0.039
# 13                                              0.046
# 14                                              0.078
# 15                                              0.040
# 16                                             -0.018
# 17                                             -0.025
# 18                                             -0.016
# 19                                             -0.001
# 20                                             -0.006
# 21                                             -0.013
# 22                                             -0.021
# 23                                             -0.013
# 24                                              0.058
# 25                                             -0.004
# 26                                             -0.008
# 27                                              0.003
# 28                                              0.055
# 29                                             -0.053
#
#     WWinsThe most important goal in sports, unless your team is not tanking  \
# 0                                                   1
# 1                                                   2
# 2                                                   4
# 3                                                   2
# 4                                                   2
# 5                                                   2
# 6                                                   3
# 7                                                   2
# 8                                                   0
# 9                                                   2
# 10                                                  1
# 11                                                  3
# 12                                                  4
# 13                                                  4
# 14                                                  3
# 15                                                  3
# 16                                                  1
# 17                                                  2
# 18                                                  2
# 19                                                  2
# 20                                                  3
# 21                                                  3
# 22                                                  2
# 23                                                  2
# 24                                                  3
# 25                                                  3
# 26                                                  2
# 27                                                  4
# 28                                                  4
# 29                                                  2
#
#     LLossesTotal count of games lost  WIN%  \
# 0                                  4   0.2
# 1                                  3   0.4
# 2                                  1   0.8
# 3                                  3   0.4
# 4                                  3   0.4
# 5                                  3   0.4
# 6                                  2   0.6
# 7                                  3   0.4
# 8                                  5   0.0
# 9                                  3   0.4
# 10                                 4   0.2
# 11                                 2   0.6
# 12                                 1   0.8
# 13                                 1   0.8
# 14                                 2   0.6
# 15                                 2   0.6
# 16                                 4   0.2
# 17                                 3   0.4
# 18                                 3   0.4
# 19                                 3   0.4
# 20                                 2   0.6
# 21                                 2   0.6
# 22                                 3   0.4
# 23                                 3   0.4
# 24                                 2   0.6
# 25                                 2   0.6
# 26                                 3   0.4
# 27                                 1   0.8
# 28                                 1   0.8
# 29                                 3   0.4
#
#     eWIN%Correlated Gaussian Expected Winning PercentageIndicates the ideal winning percentage based on offensive and defensive performance.  \
# 0                                               0.230
# 1                                               0.433
# 2                                               0.465
# 3                                               0.647
# 4                                               0.366
# 5                                               0.273
# 6                                               0.673
# 7                                               0.381
# 8                                               0.028
# 9                                               0.379
# 10                                              0.215
# 11                                              0.447
# 12                                              0.792
# 13                                              0.899
# 14                                              0.678
# 15                                              0.587
# 16                                              0.329
# 17                                              0.338
# 18                                              0.515
# 19                                              0.379
# 20                                              0.415
# 21                                              0.555
# 22                                              0.562
# 23                                              0.365
# 24                                              0.669
# 25                                              0.520
# 26                                              0.387
# 27                                              0.628
# 28                                              0.712
# 29                                              0.330
#
#     pWIN%Projected Winning PercentageEach point differential translates to 2.7 wins over the course of the season.  \
# 0                                               0.092
# 1                                               0.460
# 2                                               0.460
# 3                                               0.579
# 4                                               0.441
# 5                                               0.375
# 6                                               0.711
# 7                                               0.381
# 8                                               0.177
# 9                                               0.329
# 10                                              0.237
# 11                                              0.447
# 12                                              0.836
# 13                                              0.750
# 14                                              0.928
# 15                                              0.586
# 16                                              0.302
# 17                                              0.362
# 18                                              0.513
# 19                                              0.362
# 20                                              0.296
# 21                                              0.586
# 22                                              0.579
# 23                                              0.355
# 24                                              0.750
# 25                                              0.520
# 26                                              0.395
# 27                                              0.605
# 28                                              0.651
# 29                                              0.329
#
#     ACHAchievement Level In Terms of Wins. The metric is based on differential between actual and expected winning percentage. Positive figures indicate overachievement while negative figures indicate the team should have won more games.  \
# 0                                              -0.030
# 1                                              -0.033
# 2                                               0.335
# 3                                              -0.247
# 4                                               0.034
# 5                                               0.127
# 6                                              -0.073
# 7                                               0.019
# 8                                              -0.028
# 9                                               0.021
# 10                                             -0.015
# 11                                              0.153
# 12                                              0.008
# 13                                             -0.099
# 14                                             -0.078
# 15                                              0.013
# 16                                             -0.129
# 17                                              0.062
# 18                                             -0.115
# 19                                              0.021
# 20                                              0.185
# 21                                              0.045
# 22                                             -0.162
# 23                                              0.035
# 24                                             -0.069
# 25                                              0.080
# 26                                              0.013
# 27                                              0.172
# 28                                              0.088
# 29                                              0.070
#
#     STRKLast 5 Games StreakWinning or losing streak for the last 5 games.
# 0                                                 L 1
# 1                                                 W 1
# 2                                                 W 3
# 3                                                 W 1
# 4                                                 W 1
# 5                                                 L 1
# 6                                                 W 1
# 7                                                 L 1
# 8                                                 L 5
# 9                                                 L 1
# 10                                                W 1
# 11                                                L 1
# 12                                                W 1
# 13                                                L 1
# 14                                                L 1
# 15                                                L 1
# 16                                                L 3
# 17                                                L 3
# 18                                                W 2
# 19                                                W 1
# 20                                                W 3
# 21                                                W 3
# 22                                                W 1
# 23                                                L 1
# 24                                                W 1
# 25                                                L 1
# 26                                                W 1
# 27                                                W 4
# 28                                                L 1
# 29                                                W 1
#
# [30 rows x 24 columns]

# %% [markdown]
# ### Stat Computations for Formulas Found Below

# %%
def getParam(default = "PTS/GMPoints Per GameAverage points per game"):
    #Stuff beyond here focuses on kernel density, it is a work in progress
    if(default != "PTS/GMPoints Per GameAverage points per game"):
        print("Enter the column name you'd like to get a kernel density estimation for:")
        #Prompting user for input and calculating basic statistics, bandwidth temporarily set to .05
        #For testing purposes
        inp = input()
    else:
        inp = default
    stat = first_table.get(inp)
    return stat
stat = getParam()
#Index for purpose of making table nicer
def getIndex(indx = "TEAM"):
    if(indx!="TEAM"):
        print("Please enter the name of the column you'd like to serve as your index:")
        indx = first_table.get(input())
    else:
        indx = first_table.get(indx)
    return indx
indx = getIndex()

#Plotting Data initially
stat.plot(kind  = "hist")
avg = stat.mean()
density = np.array([])
n = first_table.shape[0]
dev = np.std(stat)

kernelEstimations = pd.DataFrame()

# %% [markdown]
# The Kernel Estimation for a Gaussian, Cosine, Triangular, and Parabolic Kernel are found below, metric used for surprise computation will be based on their average. Idea is: if between them we can found a standard density, we can find values that are more likely to be outliers. Other idea: find outliers for every one and check for commonalities.

# %% [markdown]
# ### Scikit learn citation because their software is utilized
# @article{scikit-learn,
#  title={Scikit-learn: Machine Learning in {P}ython},
#  author={Pedregosa, F. and Varoquaux, G. and Gramfort, A. and Michel, V.
#          and Thirion, B. and Grisel, O. and Blondel, M. and Prettenhofer, P.
#          and Weiss, R. and Dubourg, V. and Vanderplas, J. and Passos, A. and
#          Cournapeau, D. and Brucher, M. and Perrot, M. and Duchesnay, E.},
#  journal={Journal of Machine Learning Research},
#  volume={12},
#  pages={2825--2830},
#  year={2011}
# }

# %%
# Using cosine kernel function to get estimate for log density
def cosKernel(stat):
    stat = stat.to_numpy().reshape(-1,1) 
    l = neighbors.KernelDensity(kernel = 'cosine').fit(stat)
    cos_density = l.score_samples(stat)
    return cos_density

# %%
# Using gaussian kernel function to get estimate for log density
def gaussKernel(stat):
    stat = stat.to_numpy().reshape(-1,1) 
    l = neighbors.KernelDensity(kernel = 'gaussian').fit(stat)
    density = l.score_samples(stat)
    return density

# %%
# Using linear kernel function to get estimate for log density
def expKernel(stat):
    stat = stat.to_numpy().reshape(-1,1) 
    l = neighbors.KernelDensity(kernel = 'exponential').fit(stat)
    triDensity = l.score_samples(stat)
    return triDensity

# %%
# converted to Proportion for u < 1 supported functions
def toProp(number):
    return number/max(number)

# %%
# Using epanechnikov kernel function to get estimate for log density
def parabolicKernel(stat):
    stat = stat.to_numpy().reshape(-1,1) 
    l = neighbors.KernelDensity(kernel = 'epanechnikov').fit(stat)
    epDensity = l.score_samples(stat)
    return epDensity

# %%
#Creates normal distribution (we have standardized data) and calculates P-value with the null hypothesis being no systematic error
def retPVal(col):
    #Since we have a normal distribution, starting by obtaining the z-score
    mean = col.mean()
    std = np.std(col)
    array = np.array([])
    for i in np.arange(len(col)):
        array = np.append(array, col.iloc[i] - mean)
        
    #Now obtaining legitimate p-values
    z_scores = array/std
    for l in np.arange(len(z_scores)):
        cdf = st.norm.cdf(z_scores[l])
        z_scores[l] = min(cdf, 1-cdf)
    return pd.Series(z_scores, index = col.index)

# %% [markdown]
# ## Kernel Values Data

# %%
# Assigning initial kernal estimations
def kernelEstimator(indx, stat):
    kernelEstimate = pd.DataFrame()
    kernelEstimate = kernelEstimate.assign(Data_Index = indx, Data_Point = stat,Gaussian = gaussKernel(stat),
                                               Epanechnikov = parabolicKernel(stat), Exponential = expKernel(stat),
                                               Cosine = cosKernel(stat))
    # temporary sort for some visualization of surprise
    kernelEstimate = kernelEstimate.sort_values(by = "Gaussian", ascending = False)
    return kernelEstimate
kernelEstimation = kernelEstimator(indx, stat)
kernelEstimation
# Out:
#        Data_Index  Data_Point  Gaussian  Epanechnikov  Exponential    Cosine
# 27        Toronto       116.2 -2.577962     -2.333044    -2.575014 -2.324728
# 6          Dallas       115.8 -2.591776     -2.617296    -2.636409 -2.636240
# 26    San Antonio       116.6 -2.615355     -2.292635    -2.533969 -2.274873
# 25     Sacramento       116.6 -2.615355     -2.292635    -2.533969 -2.274873
# 0         Atlanta       115.0 -2.689539     -2.847312    -2.674663 -2.827365
# 23        Phoenix       117.0 -2.714933     -2.577022    -2.688015 -2.568766
# 14        Memphis       114.8 -2.716265     -2.847312    -2.684348 -2.827365
# 22   Philadelphia       120.0 -2.759223     -2.273026    -2.691940 -2.251443
# 12    LA Clippers       119.8 -2.767984     -2.364460    -2.695215 -2.331425
# 18    New Orleans       120.2 -2.778501     -2.282782    -2.749205 -2.272687
# 29     Washington       111.8 -2.788859     -2.659260    -2.716300 -2.627505
# 2        Brooklyn       112.2 -2.791300     -2.551046    -2.750252 -2.549300
# 5       Cleveland       111.6 -2.800368     -2.603690    -2.741960 -2.596194
# 21        Orlando       119.6 -2.802047     -2.453408    -2.759787 -2.434441
# 3       Charlotte       114.0 -2.812668     -2.847312    -2.736306 -2.827365
# 13      LA Lakers       113.8 -2.831400     -3.015935    -2.755569 -2.974391
# 9    Golden State       112.8 -2.833880     -3.194183    -2.827621 -3.180422
# 19       New York       110.8 -2.904050     -3.146555    -2.902212 -3.161550
# 10        Houston       110.0 -2.982687     -2.995732    -2.941105 -3.002592
# 11        Indiana       109.4 -2.996064     -2.864704    -2.944051 -2.865471
# 1          Boston       108.8 -3.003869     -2.995732    -2.979759 -3.002592
# 24       Portland       120.8 -3.018420     -2.995732    -3.062748 -3.002592
# 28           Utah       108.0 -3.040088     -2.995732    -3.017717 -3.002592
# 17      Minnesota       118.0 -3.101794     -3.688879    -3.012922 -3.642762
# 16      Milwaukee       107.4 -3.124509     -2.864704    -3.052560 -2.865471
# 20  Oklahoma City       105.0 -3.213439     -2.780621    -3.145212 -2.768626
# 15          Miami       104.6 -3.216379     -2.659260    -3.085828 -2.627505
# 7          Denver       104.4 -3.260733     -2.733368    -3.146441 -2.711054
# 4         Chicago       106.8 -3.276090     -3.194183    -3.173352 -3.180422
# 8         Detroit       100.4 -4.319627     -3.688879    -4.048488 -3.642762

# %%
# Calculating their average
def surprise_estimator(kernelEstimation):
    numDevMax = (kernelEstimation.get("Data_Point").max() - kernelEstimation.get("Data_Point").mean())/kernelEstimation.get("Data_Point").std()
    numDevMin = (kernelEstimation.get("Data_Point").min() - kernelEstimation.get("Data_Point").mean())/kernelEstimation.get("Data_Point").std()
    numDev = max(numDevMax, numDevMin)
    if(numDev > 3.2):
        metric = retPVal(kernelEstimation.get("Exponential"))
    elif((numDev <=3.2) & (numDev >= 2)):
        metric = retPVal(kernelEstimation.get("Gaussian"))
    else:
        metric = retPVal(kernelEstimation.get("Exponential")+kernelEstimation.get("Epanechnikov"))          
    # Surprise Metric
    kernelEstimation  = kernelEstimation.assign(Surprise = -np.log2(metric))
    kernelEstimation = kernelEstimation.sort_values(by = "Surprise", ascending = False)
    return kernelEstimation
kernelEstimation = surprise_estimator(kernelEstimation)
kernelEstimation
# Out:
#        Data_Index  Data_Point  Gaussian  Epanechnikov  Exponential    Cosine  \
# 8         Detroit       100.4 -4.319627     -3.688879    -4.048488 -3.642762
# 17      Minnesota       118.0 -3.101794     -3.688879    -3.012922 -3.642762
# 26    San Antonio       116.6 -2.615355     -2.292635    -2.533969 -2.274873
# 25     Sacramento       116.6 -2.615355     -2.292635    -2.533969 -2.274873
# 27        Toronto       116.2 -2.577962     -2.333044    -2.575014 -2.324728
# 4         Chicago       106.8 -3.276090     -3.194183    -3.173352 -3.180422
# 22   Philadelphia       120.0 -2.759223     -2.273026    -2.691940 -2.251443
# 18    New Orleans       120.2 -2.778501     -2.282782    -2.749205 -2.272687
# 12    LA Clippers       119.8 -2.767984     -2.364460    -2.695215 -2.331425
# 21        Orlando       119.6 -2.802047     -2.453408    -2.759787 -2.434441
# 6          Dallas       115.8 -2.591776     -2.617296    -2.636409 -2.636240
# 23        Phoenix       117.0 -2.714933     -2.577022    -2.688015 -2.568766
# 24       Portland       120.8 -3.018420     -2.995732    -3.062748 -3.002592
# 19       New York       110.8 -2.904050     -3.146555    -2.902212 -3.161550
# 2        Brooklyn       112.2 -2.791300     -2.551046    -2.750252 -2.549300
# 9    Golden State       112.8 -2.833880     -3.194183    -2.827621 -3.180422
# 28           Utah       108.0 -3.040088     -2.995732    -3.017717 -3.002592
# 5       Cleveland       111.6 -2.800368     -2.603690    -2.741960 -2.596194
# 1          Boston       108.8 -3.003869     -2.995732    -2.979759 -3.002592
# 29     Washington       111.8 -2.788859     -2.659260    -2.716300 -2.627505
# 10        Houston       110.0 -2.982687     -2.995732    -2.941105 -3.002592
# 20  Oklahoma City       105.0 -3.213439     -2.780621    -3.145212 -2.768626
# 16      Milwaukee       107.4 -3.124509     -2.864704    -3.052560 -2.865471
# 7          Denver       104.4 -3.260733     -2.733368    -3.146441 -2.711054
# 11        Indiana       109.4 -2.996064     -2.864704    -2.944051 -2.865471
# 0         Atlanta       115.0 -2.689539     -2.847312    -2.674663 -2.827365
# 14        Memphis       114.8 -2.716265     -2.847312    -2.684348 -2.827365
# 13      LA Lakers       113.8 -2.831400     -3.015935    -2.755569 -2.974391
# 15          Miami       104.6 -3.216379     -2.659260    -3.085828 -2.627505
# 3       Charlotte       114.0 -2.812668     -2.847312    -2.736306 -2.827365
#
#      Surprise
# 8   11.718726
# 17   4.546547
# 26   3.595957
# 25   3.595957
# 27   3.248130
# 4    3.036028
# 22   3.018048
# 18   2.760522
# 12   2.658329
# 21   2.135354
# 6    2.009440
# 23   1.975104
# 24   1.961750
# 19   1.932752
# 2    1.867804
# 9    1.853733
# 28   1.829682
# 5    1.741852
# 1    1.723000
# 29   1.660153
# 10   1.618668
# 20   1.589749
# 16   1.567473
# 7    1.472535
# 11   1.303176
# 0    1.296851
# 14   1.274909
# 13   1.219890
# 15   1.163076
# 3    1.161495

# %%
# A grouping of the entire kernel estimation process
def surprise_Table(Table, index = "TEAM"):
    temp = pcaPrep(Table)
    if(isinstance(index, str)):
        index = Table.get(index)
    sum_surprise  = pd.Series(np.zeros(Table.shape[0]))
    for col in temp.columns:
        stat = temp.get(col)
        KernelTable = kernelEstimator(index, stat)
        print(KernelTable)
        KernelTable = surprise_estimator(KernelTable)
        print(KernelTable)
        Table[col] = KernelTable.get("Surprise")
        sum_surprise+=Table[col]
    sum_surprise = sum_surprise.array
    Table = Table.set_index(index)
    Table = Table.assign(mean_surprise = np.round(sum_surprise/Table.shape[1],2))
    # Sorting table for easier visualization
    Table = Table.sort_values(by = "mean_surprise", ascending  = False)
    return Table
modTable = first_table
surpriseTable = surprise_Table(first_table)
surpriseTable
# Out:
#        Data_Index  Data_Point  Gaussian  Epanechnikov  Exponential    Cosine
# 0         Atlanta    2.656033 -0.918939     -0.287682    -0.693147 -0.241564
# 1          Boston    2.656033 -0.918939     -0.287682    -0.693147 -0.241564
# 28           Utah    2.656033 -0.918939     -0.287682    -0.693147 -0.241564
# 27        Toronto    2.656033 -0.918939     -0.287682    -0.693147 -0.241564
# 26    San Antonio    2.656033 -0.918939     -0.287682    -0.693147 -0.241564
# 25     Sacramento    2.656033 -0.918939     -0.287682    -0.693147 -0.241564
# 24       Portland    2.656033 -0.918939     -0.287682    -0.693147 -0.241564
# 23        Phoenix    2.656033 -0.918939     -0.287682    -0.693147 -0.241564
# 22   Philadelphia    2.656033 -0.918939     -0.287682    -0.693147 -0.241564
# 21        Orlando    2.656033 -0.918939     -0.287682    -0.693147 -0.241564
# 20  Oklahoma City    2.656033 -0.918939     -0.287682    -0.693147 -0.241564
# 19       New York    2.656033 -0.918939     -0.287682    -0.693147 -0.241564
# 18    New Orleans    2.656033 -0.918939     -0.287682    -0.693147 -0.241564
# 17      Minnesota    2.656033 -0.918939     -0.287682    -0.693147 -0.241564
# 16      Milwaukee    2.656033 -0.918939     -0.287682    -0.693147 -0.241564
# 15          Miami    2.656033 -0.918939     -0.287682    -0.693147 -0.241564
# 14        Memphis    2.656033 -0.918939     -0.287682    -0.693147 -0.241564
# 13      LA Lakers    2.656033 -0.918939     -0.287682    -0.693147 -0.241564
# 12    LA Clippers    2.656033 -0.918939     -0.287682    -0.693147 -0.241564
# 11        Indiana    2.656033 -0.918939     -0.287682    -0.693147 -0.241564
# 10        Houston    2.656033 -0.918939     -0.287682    -0.693147 -0.241564
# 9    Golden State    2.656033 -0.918939     -0.287682    -0.693147 -0.241564
# 8         Detroit    2.656033 -0.918939     -0.287682    -0.693147 -0.241564
# 7          Denver    2.656033 -0.918939     -0.287682    -0.693147 -0.241564
# 6          Dallas    2.656033 -0.918939     -0.287682    -0.693147 -0.241564
# 5       Cleveland    2.656033 -0.918939     -0.287682    -0.693147 -0.241564
# 4         Chicago    2.656033 -0.918939     -0.287682    -0.693147 -0.241564
# 3       Charlotte    2.656033 -0.918939     -0.287682    -0.693147 -0.241564
# 2        Brooklyn    2.656033 -0.918939     -0.287682    -0.693147 -0.241564
# 29     Washington    2.656033 -0.918939     -0.287682    -0.693147 -0.241564
#        Data_Index  Data_Point  Gaussian  Epanechnikov  Exponential    Cosine  \
# 0         Atlanta    2.656033 -0.918939     -0.287682    -0.693147 -0.241564
# 1          Boston    2.656033 -0.918939     -0.287682    -0.693147 -0.241564
# 2        Brooklyn    2.656033 -0.918939     -0.287682    -0.693147 -0.241564
# 3       Charlotte    2.656033 -0.918939     -0.287682    -0.693147 -0.241564
# 4         Chicago    2.656033 -0.918939     -0.287682    -0.693147 -0.241564
# 5       Cleveland    2.656033 -0.918939     -0.287682    -0.693147 -0.241564
# 6          Dallas    2.656033 -0.918939     -0.287682    -0.693147 -0.241564
# 7          Denver    2.656033 -0.918939     -0.287682    -0.693147 -0.241564
# 8         Detroit    2.656033 -0.918939     -0.287682    -0.693147 -0.241564
# 9    Golden State    2.656033 -0.918939     -0.287682    -0.693147 -0.241564
# 10        Houston    2.656033 -0.918939     -0.287682    -0.693147 -0.241564
# 11        Indiana    2.656033 -0.918939     -0.287682    -0.693147 -0.241564
# 12    LA Clippers    2.656033 -0.918939     -0.287682    -0.693147 -0.241564
# 13      LA Lakers    2.656033 -0.918939     -0.287682    -0.693147 -0.241564
# 14        Memphis    2.656033 -0.918939     -0.287682    -0.693147 -0.241564
# 15          Miami    2.656033 -0.918939     -0.287682    -0.693147 -0.241564
# 16      Milwaukee    2.656033 -0.918939     -0.287682    -0.693147 -0.241564
# 17      Minnesota    2.656033 -0.918939     -0.287682    -0.693147 -0.241564
# 18    New Orleans    2.656033 -0.918939     -0.287682    -0.693147 -0.241564
# 19       New York    2.656033 -0.918939     -0.287682    -0.693147 -0.241564
# 20  Oklahoma City    2.656033 -0.918939     -0.287682    -0.693147 -0.241564
# 21        Orlando    2.656033 -0.918939     -0.287682    -0.693147 -0.241564
# 22   Philadelphia    2.656033 -0.918939     -0.287682    -0.693147 -0.241564
# 23        Phoenix    2.656033 -0.918939     -0.287682    -0.693147 -0.241564
# 24       Portland    2.656033 -0.918939     -0.287682    -0.693147 -0.241564
# 25     Sacramento    2.656033 -0.918939     -0.287682    -0.693147 -0.241564
# 26    San Antonio    2.656033 -0.918939     -0.287682    -0.693147 -0.241564
# 27        Toronto    2.656033 -0.918939     -0.287682    -0.693147 -0.241564
# 28           Utah    2.656033 -0.918939     -0.287682    -0.693147 -0.241564
# 29     Washington    2.656033 -0.918939     -0.287682    -0.693147 -0.241564
#
#     Surprise
# 0   2.656033
# 1   2.656033
# 2   2.656033
# 3   2.656033
# 4   2.656033
# 5   2.656033
# 6   2.656033
# 7   2.656033
# 8   2.656033
# 9   2.656033
# 10  2.656033
# 11  2.656033
# 12  2.656033
# 13  2.656033
# 14  2.656033
# 15  2.656033
# 16  2.656033
# 17  2.656033
# 18  2.656033
# 19  2.656033
# 20  2.656033
# 21  2.656033
# 22  2.656033
# 23  2.656033
# 24  2.656033
# 25  2.656033
# 26  2.656033
# 27  2.656033
# 28  2.656033
# 29  2.656033
#        Data_Index  Data_Point  Gaussian  Epanechnikov  Exponential    Cosine
# 13      LA Lakers    1.332639 -0.996732     -0.374533    -0.879892 -0.332453
# 5       Cleveland    1.436632 -0.998048     -0.377620    -0.822023 -0.335834
# 28           Utah    1.436664 -0.998050     -0.377625    -0.822007 -0.335839
# 1          Boston    1.436726 -0.998054     -0.377633    -0.821979 -0.335849
# 22   Philadelphia    1.436741 -0.998055     -0.377635    -0.821974 -0.335852
# 23        Phoenix    1.436900 -0.998065     -0.377657    -0.821928 -0.335877
# 16      Milwaukee    1.436935 -0.998067     -0.377662    -0.821921 -0.335883
# 11        Indiana    1.436937 -0.998068     -0.377662    -0.821920 -0.335883
# 21        Orlando    1.437042 -0.998074     -0.377676    -0.821914 -0.335900
# 0         Atlanta    1.437195 -0.998084     -0.377697    -0.821916 -0.335925
# 7          Denver    1.437199 -0.998084     -0.377698    -0.821917 -0.335926
# 4         Chicago    1.437258 -0.998088     -0.377706    -0.821926 -0.335936
# 2        Brooklyn    1.437272 -0.998089     -0.377708    -0.821930 -0.335938
# 6          Dallas    1.437378 -0.998096     -0.377722    -0.821964 -0.335955
# 9    Golden State    1.437388 -0.998097     -0.377724    -0.821968 -0.335957
# Brooklyn                                                     W 3
# Milwaukee                                                    L 3
# Minnesota                                                    L 3
# Washington                                                   W 1
# Oklahoma City                                                W 3
# New Orleans                                                  W 2
# Indiana                                                      L 1
# Denver                                                       L 1
# Orlando                                                      W 3
# Portland                                                     W 1
# Houston                                                      W 1
# San Antonio                                                  W 1
# Toronto                                                      W 4
# Golden State                                                 L 1
# Phoenix                                                      L 1
# Dallas                                                       W 1
# Miami                                                        L 1
# Boston                                                       W 1
# Chicago                                                      W 1
# New York                                                     W 1
# Cleveland                                                    L 1
# Sacramento                                                   L 1
#
#                mean_surprise
# TEAM
# Detroit                 5.38
# Memphis                 2.96
# Atlanta                 2.72
# LA Lakers               2.44
# LA Clippers             2.32
# Utah                    2.30
# Philadelphia            2.29
# Charlotte               2.03
# Brooklyn                2.01
# Milwaukee               1.73
# Minnesota               1.64
# Washington              1.59
# Oklahoma City           1.57
# New Orleans             1.54
# Indiana                 1.53
# Denver                  1.53
# Orlando                 1.53
# Portland                1.44
# Houston                 1.42
# San Antonio             1.19
# Toronto                 1.19
# Golden State            1.18
# Phoenix                 1.18
# Dallas                  1.17
# Miami                   1.17
# Boston                  1.16
# Chicago                 1.16
# New York                1.15
# Cleveland               1.15
# Sacramento              1.15
#
# [30 rows x 25 columns]

# %% [markdown]
# The Exponential Density should apply to a more fat-tailed distribution, and makes less assumption of outliers, others assume a less spread out (parabolic and cosine) or normal (gaussian) distribution. To truly quantify an outlier, exponential density should be used.

# %% [markdown]
# # Visualization Below

# %%
surpriseTable.plot(kind = "barh", y = "mean_surprise")

# %%
surpriseTable.get("mean_surprise").plot(kind = "hist")

# %% [markdown]
# # PCA and Singular Value Decomp for Cross Column Correlation Lie Ahead

# %% [markdown]
# PCA is Combined with Kernel Density to approximate the systematic bias both by row and column. The systematic grouping of these 2 methods allows us to triangulate value-outliers at their percise position.

# %%
def loader(first_table):
    # Giving user option to change dataset
    print("Would you like to change the data set you are working with?")
    if(input().upper() == "YES"):
        print("Enter the URL below:")
        nam = input()
        frame = pd.read_html(nam)
        table = frame[1]
        return table
    else:
        return first_table
first_table = loader(first_table)
print("\ndataset below:")
first_table
# Out:
# Would you like to change the data set you are working with?
# https://www.nbastuffer.com/2019-2020-nba-team-stats/
#
# dataset below:
#     RANK           TEAM  CONF   DIVISION        GP  \
# 0    NaN        Atlanta  East  Southeast  2.656033
# 1    NaN         Boston  East   Atlantic  2.656033
# 2    NaN       Brooklyn  East   Atlantic  2.656033
# 3    NaN      Charlotte  East  Southeast  2.656033
# 4    NaN        Chicago  East    Central  2.656033
# 5    NaN      Cleveland  East    Central  2.656033
# 6    NaN         Dallas  West  Southwest  2.656033
# 7    NaN         Denver  West  Northwest  2.656033
# 8    NaN        Detroit  East    Central  2.656033
# 9    NaN   Golden State  West    Pacific  2.656033
# 10   NaN        Houston  West  Southwest  2.656033
# 11   NaN        Indiana  East    Central  2.656033
# 12   NaN    LA Clippers  West    Pacific  2.656033
# 13   NaN      LA Lakers  West    Pacific  2.656033
# 14   NaN        Memphis  West  Southwest  2.656033
# 3                                         6.986393
# 4                                         2.253879
# 5                                         1.463367
# 6                                         2.448047
# 7                                         1.486139
# 8                                         3.153924
# 9                                         1.216068
# 10                                        1.431413
# 11                                        2.448047
# 12                                        2.481518
# 13                                        1.115967
# 14                                        2.396291
# 15                                        1.820539
# 16                                        3.832190
# 17                                        3.799349
# 18                                        6.112556
# 19                                        1.070789
# 20                                        2.443684
# 21                                        2.505031
# 22                                        1.587751
# 23                                        1.825550
# 24                                        1.667135
# 25                                        2.169538
# 26                                        2.169538
# 27                                        1.945794
# 28                                        4.036903
# 29                                        2.448047
#
#     OEFFOffensive EfficiencyPoints scored per 100 possessions.  ...  \
# 0                                            2.309276           ...
# 1                                            2.982355           ...
# 2                                            2.955972           ...
# 3                                            2.529501           ...
# 4                                            1.100733           ...
# 5                                            1.229765           ...
# 6                                            1.222493           ...
# 7                                            2.769897           ...
# 8                                            1.777482           ...
# 9                                            1.283628           ...
# 10                                           2.563207           ...
# 11                                           2.926969           ...
# 12                                           2.454936           ...
# 13                                           1.029559           ...
# 14                                           1.434216           ...
# 15                                           2.794417           ...
# 16                                           7.141299           ...
# 17                                           1.142115           ...
# 18                                           2.595959           ...
# 19                                           2.074052           ...
# 20                                           3.326524           ...
# 21                                           2.914912           ...
# 22                                           7.002622           ...
# 23                                           1.526620           ...
# 24                                           3.317208           ...
# 25                                           3.012367           ...
# 26                                           1.688626           ...
# 27                                           1.688626           ...
# 28                                           1.635245           ...
# 29                                           1.141046           ...
#
#     SARSchedule Adjusted RatingAn evaluation of teams based on efficiency differential and strength of schedule  \
# 0                                            7.477833
# 1                                            1.996388
# 2                                            1.009885
# 3                                            2.561998
# 4                                            2.495033
# 5                                            2.579672
# 6                                            1.398977
# 7                                            1.084022
# 8                                            3.254784
# 9                                            3.107217
# 10                                           3.111286
# 11                                           2.678198
# 12                                           2.717895
# 13                                           5.728180
# 14                                           2.826871
# 15                                           1.803315
# 16                                           1.516629
# 17                                           3.020188
# 18                                           2.572120
# 19                                           1.592312
# 20                                           1.311690
# 21                                           2.019936
# 22                                           2.190657
# 23                                           3.158470
# 24                                           1.066745
# 25                                           1.852638
# 26                                           2.475571
# 27                                           2.675947
# 28                                           1.360492
# 29                                           2.065784
#
#     CONSConsistency RatingConsistency based on game-by-game efficiency differential variation. The higher the team has a consistency rating, the more unpredictable it is.  \
# 0                                            1.184802
# 1                                            1.210954
# 2                                            8.680942
# 3                                            1.071120
# 4                                            1.136697
# 5                                            1.035951
# 6                                            1.464961
# 7                                            2.259940
# 8                                            1.037510
# 9                                            1.184802
# 10                                           1.962997
# 11                                           1.972366
# 12                                           2.242717
# 13                                           1.187880
# 14                                           8.488329
# 15                                           1.901695
# 16                                           2.031148
# 17                                           1.852380
# 18                                           1.029695
# 19                                           1.812804
# 20                                           8.397449
# 21                                           1.325483
# 22                                           1.135830
# 23                                           2.254782
# 24                                           2.116462
# 25                                           1.797457
# 26                                           1.942643
# 27                                           1.942643
# 28                                           1.443659
# 29                                           1.848081
#
#     A4FAdjusted Four FactorsCalculated by applying weights to the differentials of offensive and defensive four factors. A4F explains the specified proportion of variability in wins.  \
# 0                                            1.930972
# 1                                            1.435166
# 2                                            2.037191
# 3                                            2.048642
# 4                                            1.462899
# 5                                            1.865157
# 6                                            2.044183
# 7                                            1.802387
# 8                                            1.090665
# 9                                            2.037191
# 10                                           1.385309
# 11                                           1.504466
# 12                                           1.678654
# 13                                           2.487972
# 14                                          13.487472
# 15                                           1.774812
# 16                                           1.768059
# 17                                           1.481457
# 18                                           1.834780
# 19                                           2.046757
# 20                                           2.037191
# 21                                           1.919565
# 22                                           1.654352
# 23                                           1.919565
# 24                                           4.862145
# 25                                           2.048642
# 26                                           2.015689
# 27                                           2.008852
# 28                                           4.122913
# 29                                           2.709000
#
#     WWinsThe most important goal in sports, unless your team is not tanking  \
# 0                                            3.659530
# 1                                            2.290355
# 2                                            2.286339
# 3                                            2.290355
# 4                                            2.290355
# 5                                            2.290355
# 6                                            1.155333
# 7                                            2.290355
# 8                                           11.592953
# 9                                            2.290355
# 10                                           3.659530
# 11                                           1.155333
# 12                                           2.286339
# 13                                           2.286339
# 14                                           1.155333
# 15                                           1.155333
# 16                                           3.659530
# 17                                           2.290355
# 18                                           2.290355
# 19                                           2.290355
# 20                                           1.155333
# 21                                           1.155333
# 22                                           2.290355
# 23                                           2.290355
# 24                                           1.155333
# 25                                           1.155333
# 26                                           2.290355
# 27                                           2.286339
# 28                                           2.286339
# 29                                           2.290355
#
#     LLossesTotal count of games lost       WIN%  \
# 0                           2.325793   2.534200
# 1                           1.923389   2.001321
# 2                           2.861444   2.984360
# 3                           1.923389   2.001321
# 4                           1.923389   2.001321
# 5                           1.923389   2.001321
# 6                           1.625052   1.582136
# 7                           1.923389   2.001321
# 8                          14.223932  12.947343
# 9                           1.923389   2.001321
# 10                          2.325793   2.534200
# 11                          1.625052   1.582136
# 12                          2.861444   2.984360
# 13                          2.861444   2.984360
# 14                          1.625052   1.582136
# 15                          1.625052   1.582136
# 16                          2.325793   2.534200
# 17                          1.923389   2.001321
# 18                          1.923389   2.001321
# 19                          1.923389   2.001321
# 20                          1.625052   1.582136
# 21                          1.625052   1.582136
# 22                          1.923389   2.001321
# 23                          1.923389   2.001321
# 24                          1.625052   1.582136
# 25                          1.625052   1.582136
# 26                          1.923389   2.001321
# 27                          2.861444   2.984360
# 28                          2.861444   2.984360
# 29                          1.923389   2.001321
#
#     eWIN%Correlated Gaussian Expected Winning PercentageIndicates the ideal winning percentage based on offensive and defensive performance.  \
# 0                                            1.723787
# 1                                            2.025600
# 2                                            2.085597
# 3                                            1.102607
# 4                                            1.666893
# 5                                            1.140929
# 6                                            1.142233
# 7                                            1.770809
# 8                                           11.706128
# 9                                            1.757633
# 10                                           1.999376
# 11                                           2.061583
# 12                                           3.667905
# 13                                           9.948609
# 14                                           1.196715
# 15                                           1.613675
# 16                                           1.369609
# 17                                           1.446164
# 18                                           2.018827
# 19                                           1.757633
# 20                                           1.958002
# 21                                           1.832524
# 22                                           1.789331
# 23                                           1.659567
# 24                                           1.100819
# 25                                           2.001623
# 26                                           1.808998
# 27                                           1.272412
# 28                                           1.659308
# 29                                           1.378218
#
#     pWIN%Projected Winning PercentageEach point differential translates to 2.7 wins over the course of the season.  \
# 0                                            6.683211
# 1                                            2.152014
# 2                                            2.152014
# 3                                            1.786409
# 4                                            2.109708
# 5                                            1.763294
# 6                                            1.471248
# 7                                            1.805893
# 8                                            2.936572
# 9                                            1.385989
# 10                                           1.611739
# 11                                           2.126093
# 12                                           5.070382
# 13                                           2.168192
# 14                                          11.652372
# 15                                           1.735548
# 16                                           1.139762
# 17                                           1.664938
# 18                                           2.118833
# 19                                           1.664938
# 20                                           1.084419
# 21                                           1.735548
# 22                                           1.786409
# 23                                           1.608895
# 24                                           2.168192
# 25                                           2.097966
# 26                                           1.897600
# 27                                           1.586164
# 28                                           1.178843
# 29                                           1.385989
#
#     ACHAchievement Level In Terms of Wins. The metric is based on differential between actual and expected winning percentage. Positive figures indicate overachievement while negative figures indicate the team should have won more games.  \
# 0                                            1.696656
# 1                                            1.676627
# 2                                           15.775579
# 3                                            7.329034
# 4                                            1.806209
# 5                                            1.006116
# 6                                            1.312640
# 7                                            1.837637
# 8                                            1.709343
# 9                                            1.835479
# 10                                           1.778201
# 11                                           1.396379
# 12                                           1.838203
# 13                                           1.013503
# 14                                           1.257411
# 15                                           1.840319
# 16                                           1.440548
# 17                                           1.657955
# 18                                           1.200778
# 19                                           1.835479
# 20                                           2.161198
# 21                                           1.761306
# 22                                           2.265036
# 23                                           1.802876
# 24                                           1.355662
# 25                                           1.508848
# 26                                           1.840319
# 27                                           1.804590
# 28                                           1.431576
# 29                                           1.596288
#
#     STRKLast 5 Games StreakWinning or losing streak for the last 5 games.
# 0                                                 L 1
# 1                                                 W 1
# 2                                                 W 3
# 3                                                 W 1
# 4                                                 W 1
# 5                                                 L 1
# 6                                                 W 1
# 7                                                 L 1
# 8                                                 L 5
# 9                                                 L 1
# 10                                                W 1
# 11                                                L 1
# 12                                                W 1
# 13                                                L 1
# 14                                                L 1
# 15                                                L 1
# 16                                                L 3
# 17                                                L 3
# 18                                                W 2
# 19                                                W 1
# 20                                                W 3
# 21                                                W 3
# 22                                                W 1
# 23                                                L 1
# 24                                                W 1
# 25                                                L 1
# 26                                                W 1
# 27                                                W 4
# 28                                                L 1
# 29                                                W 1
#
# [30 rows x 24 columns]

# %%
def pcaPrep(first_table):
# Finding all numerical components of the table so that pca can function
    tabl = first_table.select_dtypes(include = [np.number])
    tabl = tabl.dropna(1)
    return tabl

def obtain_variance_table(first_table):
    tabl = pcaPrep(first_table)
    scaled_data = StandardScaler().fit_transform(tabl)
    # Creating a PCA object 
    pca = PCA(n_components = (tabl.shape[1]))
    pcaData = pca.fit_transform(scaled_data)
    infoFrame = pd.DataFrame().assign(Column = ["PC" + str(i) for i in range(tabl.shape[1])], Variance_ratio = pca.explained_variance_ratio_ )
    return infoFrame
obtain_variance_table(first_table)
# Out:
#    Column  Variance_ratio
# 0     PC0        0.285852
# 1     PC1        0.194679
# 2     PC2        0.117548
# 3     PC3        0.088544
# 4     PC4        0.074778
# 5     PC5        0.060814
# 6     PC6        0.055263
# 7     PC7        0.048203
# 8     PC8        0.019775
# 9     PC9        0.017065
# 10   PC10        0.011453
# 11   PC11        0.009676
# 12   PC12        0.008452
# 13   PC13        0.004900
# 14   PC14        0.001883
# 15   PC15        0.000798
# 16   PC16        0.000281
# 17   PC17        0.000035
# 18   PC18        0.000000

# %%
def obtainPCAVals(componentNum, scaled_data):
    pca = PCA(n_components = componentNum)
    print(scaled_data)
    pcaData = pca.fit_transform(scaled_data)
    return pcaData

# %%
# Deciding how many columns need to be used: utilizing threashold of 95% of the explained variance
def elementDecider(infoFrame):
    numSum = 0
    counter = 0
    for i in infoFrame.get("Variance_ratio"):
        if(numSum < .95):
            numSum += i
            counter+=1
    return counter

#Reducing dimensionality of data into pc's, only storing what is neccessary
def reducedData(infoFrame,  scaled_data, indx):
    numCols = elementDecider(infoFrame)
    pcaData = obtainPCAVals(numCols, scaled_data)
    pcaFrame = pd.DataFrame(pcaData)
    if(not isinstance(indx, str)):
        pcaFrame = pcaFrame.set_index(indx)
    return pcaFrame

#Visualization tool for seeing grouping of elements by pc
def displayReducedData(pcaVals, xNum = 0, yNum = 1):
    # Ensuring that the elements given do not overacess table 
    if(xNum < pcaVals.shape[1]) & (yNum < pcaVals.shape[1]):
        pcaVals.plot(kind = "scatter", x = 2, y = 3)
    else:
        print("You have overaccessed the number of elements, keep in mind there are only " + str(pcaVals.shape[1]) + " elements")

# %%
#Summing p-values because PCA serves to check for systematic bias, whereas kernel density checks for accuracy
def sumRows(pcaVals):
    sumArray = np.zeros(pcaVals.shape[0])
    for i in np.arange(pcaVals.shape[1]):
        values = pcaVals.get(str(i)).array
        sumArray += values
    sumArray /= pcaVals.shape[1]
    #After obtaining sum, the average deviation from the expected value is averaged out, not taking in absolute value
    # to check for systematic error
    return sumArray

    
def pcaRowOutliers(pcaVals):
    P_val_table = pd.DataFrame()
    #Creating a table of all the PCA p-values
    for col in np.arange(0,pcaVals.shape[1]):
        P_vals =  retPVal(pcaVals.get(col))
        i = str(col)
        P_val_table[i] = P_vals
    print("The P-Values of each PCA score found below: \n")
    print(P_val_table)
    totalVar = sumRows(P_val_table)
    
    #Calculating surprise by taking negative log
    newVals = pcaVals.assign(Surprise = -np.log2(totalVar))
    newVals = newVals.sort_values(by = "Surprise", ascending = False)
    return newVals

# %%
def runPCA(table, index):
    processing_table = pcaPrep(table)
    variance_table = obtain_variance_table(table)
    pcaVals = reducedData(variance_table, StandardScaler().fit_transform(processing_table), table.get(index))
    new_pca = pcaRowOutliers(pcaVals)
    return new_pca
new_pca = runPCA(first_table, 'TEAM')
# Out:
# [[ 1.00000000e+00 -5.85119743e-01  4.01812490e+00  2.49861937e+00
#   -2.82655596e-03 -9.97470125e-02 -1.00411033e+00  1.64759729e+00
#    1.33352145e+00 -1.56461566e-01  3.82100178e+00 -5.26654732e-01
#   -2.22524683e-01  6.65118831e-01 -5.60089787e-02  3.12980126e-02
#   -2.56468722e-01  2.10028352e+00 -2.19038454e-01]
# Now that we have found individual outliers with both a column approach and a row-based approach, we group the 2 approaches using naive bayes in a manner that is easy to read. Idea: group by sum of surprise so outliers appear at the top!

# %%
def pca_kernel_combo(pcaTable,kernelTable):
    pcaSurpriseCol = new_pca.get("Surprise")
    temp = pcaPrep(kernelTable)
    for column in temp.columns:
        kernelTable[column] = (kernelTable[column].multiply(pcaSurpriseCol)).apply(np.sqrt)
    kernelTable = kernelTable.sort_values(by = "mean_surprise", ascending = False)
    return kernelTable
surpriseTable = pca_kernel_combo(new_pca, surpriseTable) 
surpriseTable
# Out:
#                RANK           TEAM  CONF   DIVISION        GP  \
# TEAM
# Atlanta         NaN        Atlanta  East  Southeast  2.852426
# Detroit         NaN        Detroit  East    Central  2.179528
# LA Lakers       NaN      LA Lakers  West    Pacific  2.762187
# Memphis         NaN        Memphis  West  Southwest  2.299288
# Brooklyn        NaN       Brooklyn  East   Atlantic  2.542399
# Oklahoma City   NaN  Oklahoma City  West  Northwest  2.583001
# Charlotte       NaN      Charlotte  East  Southeast  2.560123
# LA Clippers     NaN    LA Clippers  West    Pacific  2.293748
# Milwaukee       NaN      Milwaukee  East    Central  2.343980
# Orlando         NaN        Orlando  East  Southeast  2.489563
# Philadelphia    NaN   Philadelphia  East   Atlantic  2.215141
# Washington      NaN     Washington  East  Southeast  2.320696
# Houston         NaN        Houston  West  Southwest  2.133430
# Denver          NaN         Denver  West  Northwest  2.174043
# New Orleans     NaN    New Orleans  West  Southwest  2.191536
# Utah            NaN           Utah  West  Northwest  2.011105
# Minnesota       NaN      Minnesota  West  Northwest  1.979080
# Indiana         NaN        Indiana  East    Central  2.079000
# Sacramento      NaN     Sacramento  West    Pacific  2.133679
# Toronto         NaN        Toronto  East   Atlantic  2.098243
# Portland        NaN       Portland  West  Northwest  2.105371
# Chicago         NaN        Chicago  East    Central  2.144596
# Phoenix         NaN        Phoenix  West    Pacific  1.985017
# Golden State    NaN   Golden State  West    Pacific  2.072944
# Boston          NaN         Boston  East   Atlantic  2.050337
# San Antonio     NaN    San Antonio  West  Southwest  1.999864
# New York        NaN       New York  East   Atlantic  1.954625
# Cleveland       NaN      Cleveland  East    Central  1.958738
# Dallas          NaN         Dallas  West  Southwest  1.935892
# Miami           NaN          Miami  East  Southeast  1.874552
#
#                PTS/GMPoints Per GameAverage points per game  \
# TEAM
# Atlanta                                            1.993163
# Detroit                                            4.578108
# LA Lakers                                          1.871961
# Memphis                                            1.593002
# Brooklyn                                           2.132027
# Oklahoma City                                      1.998353
# Charlotte                                          1.692984
# LA Clippers                                        2.294739
# Milwaukee                                          1.800683
# Orlando                                            2.232242
# Philadelphia                                       2.361282
# Washington                                         1.834744
# Houston                                            1.665485
# Denver                                             1.618767
# New Orleans                                        2.234228
# Utah                                               1.669191
# Minnesota                                          2.589331
# Indiana                                            1.456261
# Sacramento                                         2.482673
# Toronto                                            2.320362
# Portland                                           1.809397
# Chicago                                            2.292882
# Phoenix                                            1.711759
# Golden State                                       1.731787
# Boston                                             1.651396
# San Antonio                                        2.326971
# New York                                           1.667381
# Cleveland                                          1.586226
# 513004          Office of the Chief Operating Officer           1001001111
# 513212          Office of the Chief Operating Officer           1001001111
# 500011                             Council District 1           1101000001
# 500134                             Council District 1           1101000001
# 502010                             Council District 1           1101000001
# 502012                             Council District 1           1101000001
# 502021                             Council District 1           1101000001
#
#                                                  account
# account_number
# 500011                                    Salaried Wages
# 502012                         CERS - General Retirement
# 502021                      Supp Pens Sav Plan Mandatory
# 502022                      Supp Pens Sav Plan Voluntary
# 502043                   CERS-UAAL Unclass-Unrepresented
# 502046                           Workers' Comp Insurance
# 502047                             Flexible Benefit Plan
# 502048                          Risk Mgmt Administration
# 502049                              Long Term Disability
# 502050                            Unemployment Insurance
# 502051                           Fica/Medicare Insurance
# 502052                       Retiree Health Contribution
# 502077                              Employer Contrib RMT
# 502094                            SPSP-H General Members
# 511010                                   Office Supplies
# 511011                                   Postage/Mailing
# 511048                              Computer Accessories
# 511117                                      Copier Paper
# 512000                   1 Day Trips-Less Than 200 Miles
# 512043                                   Fees-Membership
# 512057                     Meals With Non-City Employees
# 512059          Miscellaneous Professional/Technical Ser
# 512064                                    Parking Stamps
# 512070                                  Training-In Town
# 512072                               Travel-Non Training
# 512073                                   Travel-Training
# 512077                                Photocopy Services
# 512080                               Print Shop Services
# 512108                  Interfund Environmental Services
# 512162                            SAP Support Allocation
# ...                                                  ...
# 514112                   Wireless Communication Transfer
# 516015                          Transportation Allowance
# 516021          Information Technology Services Transfer
# 500011                                    Salaried Wages
# 500121                                      Hourly Wages
# 500134                               Sick Leave - Hourly
# 502012                         CERS - General Retirement
# 502021                      Supp Pens Sav Plan Mandatory
# 502022                      Supp Pens Sav Plan Voluntary
# 502039                         CERS-UAAL MEA Supervisory
# 502042                CERS-UAAL Classified Unrepresented
# 502046                           Workers' Comp Insurance
# 502047                             Flexible Benefit Plan
# 502048                          Risk Mgmt Administration
# 502049                              Long Term Disability
# 502050                            Unemployment Insurance
# 502051                           Fica/Medicare Insurance
# 502052                       Retiree Health Contribution
# 502073                                   SPSP-H Budgeted
# 511010                                   Office Supplies
# 511011                                   Postage/Mailing
# 512077                                Photocopy Services
# 512245                                  Wireless Stipend
# 513004                    Network Access - Discretionary
# 513212                                Voice/Data Network
# 500011                                    Salaried Wages
# 500134                               Sick Leave - Hourly
# 502010                         CERS - Legislative Retire
# 502012                         CERS - General Retirement
# 502021                      Supp Pens Sav Plan Mandatory
#
# [69 rows x 8 columns]
#                   amount  report_fy budget_cycle     fund_type  fund_number  \
# account_number
# 500011          379363.0         17      adopted  General Fund       100000
# 502012          139001.0         17      adopted  General Fund       100000
# 502021            7650.0         17      adopted  General Fund       100000
# 502022            7778.0         17      adopted  General Fund       100000
# 502043            7650.0         17      adopted  General Fund       100000
# 502046            3646.0         17      adopted  General Fund       100000
# 502047           36109.0         17      adopted  General Fund       100000
# 502048            3066.0         17      adopted  General Fund       100000
# 502049            1207.0         17      adopted  General Fund       100000
# 502050             690.0         17      adopted  General Fund       100000
# 502051            5501.0         17      adopted  General Fund       100000
# 502052           17745.0         17      adopted  General Fund       100000
# 514009                     Cellular Phone Operating Cost
# 514100                                 Electric Services
# 514101                                      Gas Services
# 514112                   Wireless Communication Transfer
# 516015                          Transportation Allowance
# 516021          Information Technology Services Transfer
# 560040                                 Cap Exp-Equipment
# 500011                                    Salaried Wages
# 502012                         CERS - General Retirement
# 502021                      Supp Pens Sav Plan Mandatory
# 502022                      Supp Pens Sav Plan Voluntary
# 502043                   CERS-UAAL Unclass-Unrepresented
# 502046                           Workers' Comp Insurance
# 502047                             Flexible Benefit Plan
# 502048                          Risk Mgmt Administration
# 502049                              Long Term Disability
# 502050                            Unemployment Insurance
# 502051                           Fica/Medicare Insurance
# 502052                       Retiree Health Contribution
# 500011                                    Salaried Wages
# 500017                              Vacation Pay In Lieu
# 500055                               Bilingual - Regular
# 502012                         CERS - General Retirement
# 502021                      Supp Pens Sav Plan Mandatory
#
# [500 rows x 8 columns]

# %% [markdown]
# # Tackling the Categorical Question Below

# %% [markdown]
# The following are several categorical questions that could be tackled with this program, ultimately, this will be used in the report which assesses flaws in the data. I perceive the functionality to work something like a data spellcheck.

# %% [markdown]
# This attempts to answer the questions above but with categorical data: is there a problem and if so where is it? However it is different in that this will also attempt to answer why.

# %% [markdown]
# The program will be built upon the principals of entropy and will work something like this: languages have a structure and rules. There is a certain grammar to be followed, and the more strict the grammar is the lower a systems relative entropy (its entropy relative to the maximum entropy that could be had). Thus, more structure  = stricter interpretation of the data and outliers. If something follows the rule, it airs on the side of redundancy. Otherwise, it airs on the side of the entropy of the rule. Thus, the easiest approach to finding a numerical outlier within data is to build rules that are as abstract and all encompassing as possible (so as to avoid the need for context), and obtain the entropy of every data point in regards to whether it does/ does not follow the rules. Naturally, the data which does not follow the rules is bound to have greater entropy, but particularly if the rule is strict.

# %% [markdown]
# However, if the data set is terribly structured and the data frequently breaks rules then it is not at all surprising for a rule to be broken. If, say, every bit of data broke an entirely different rule once (the most extreme case of a dataset having a massive total entropy), it would be not at all surprising to see data break rules. Thus, the surprise will be measured as a true metric of relative entropy, meaning that we are measuring the anomaly of all the rules a piece of data broke: relative to how often and severly rules are broken. This will put things in better context. The why piece of the question after measuring this should be easy: for each piece of data, the program will store which rules the data broke: and how strict these rules were.

# %%
# Will examine whether or not a column is categorical, giving the user the opportunity to add additional numeric columns
def identifyCategorical(surpriseFrame):
    categorical_list = []
    for col in surpriseFrame.columns:
        if(not(is_numeric_dtype(surpriseFrame[col]))):
            categorical_list.append(col)
    
    # Allows fixing of default assumption that numeric columns aren't categorical
    print("Are there any numeric Columns you would consider categorical?(yes/no)")
    while(input().upper() == "YES"):
        print("Enter one such column:")
        categorical_list.append(input())
        print("Any more?")
    return categorical_list

# %% [markdown]
# Below is categorical approach, which has been updated so some remnants of previous code might remain

# %% [markdown]
# **Calculating anomaly for classification: type, whether it is an nan, and the length of the data**

# %%
# Returns suprise of type classification
def types(column):
    value_types = column.apply(classifier)
    counts  = value_types.value_counts(normalize = True)
    print(counts)
    index = counts.index
    values = counts.values
    probs = value_types.apply(giveProb, args = (np.array(index), np.array(values)))
    surpriseVal = probs.apply(surprise)
    return surpriseVal

# Obtains the type of value, even if it is currently contained within a string
def classifier(value):
    value = str(value)
    # Boolean check done manually: this is an easy check
    if(('True' in value) or ('False' in value )):
        return 'boolean'
    else:
        if(value.isnumeric()):
            return 'number'
        else:
            return 'string'
    
# Takes in a column and returns the surprise of each nan value being present (True) or not being present (False)
def nans(column):
    nan_values = column.apply(isNan)
    counts  = nan_values.value_counts(normalize = True)
    index = counts.index
    values = counts.values
    probs = nan_values.apply(giveProb, args = (np.array(index), np.array(values)))
    surpriseVal = probs.apply(surprise)
    return surpriseVal

# Takes in a column and returns the surprise of the length of each value in the column: the first and simplest of probabilistic tests
def lenCount(column):
    column = column.apply(str)
    counts = column.apply(len).value_counts(normalize = True)
    index = counts.index
    values = counts.values
    column = column.apply(len)
    probs = column.apply(giveProb, args = (np.array(index), np.array(values)))
    surpriseVal = probs.apply(surprise)
    return surpriseVal

# Calculates the surprise of a given value
def surprise(value):
    return -np.log2(value)

# Given a numerical value, finds it equivalent within the set of indices and assigns it the proper probability
def giveProb(value, index, values):
    for num in np.arange(len(index)):
        if(value == index[num]):
            return values[num]
    return values[0]
        

# NaN's aren't equal to themselves
def isNan(x):
    return x!=x

# %% [markdown]
# **The following part deals with structure: uniqueness and special characters**

# %%
# Checks for special characters within a string, calculating surprise so as to identify which character combinations are chaotic
def special_char(column):
    characters = column.apply(str).apply(char_identifier)
    counts  = characters.value_counts(normalize = True)
    index = counts.index
    values = counts.values
    probs = characters.apply(giveProb, args = (np.array(index), np.array(values)))
    surpriseVal = probs.apply(surprise)
    return surpriseVal

# Checks if a single entry of any data type contains special symbols and returns all that it contains
def char_identifier(entry):
    charList = np.array(['<', '>', '!', '#','_','@','$','&','*','^', ' ', '/', '-','"','(', ',', ')', '?', '.'])
    ret_string = ""
    for i in charList:
        if(i in entry):
            ret_string += i
    return ret_string

# Simpler approach here: if the value counts of certain elements are greater when they should be unique, they are more suprising
# If they are non-unique when they are supposed to be unique, also more surprising. Done with binary classification
def uniques(column):
    # Counting number of each value and returning whether or not it is a singular unique value,
    #then counting truly unique values
    vals = column.value_counts().apply(isunique)
    vals = column.apply(unique_assignment, args = [vals])
    counts = vals.value_counts(normalize = True)
    index = counts.index
    values = counts.values
    probs = vals.apply(giveProb, args = (np.array(index), np.array(values)))
    surpriseVal = probs.apply(surprise)
    # Note: if all values unique/non unique this will provide definite outcome because no room for uncertainty
    return surpriseVal

# Returns whether the count of a value is 1
def isunique(val):
    return (val == 1)

# Maintains individual values without grouping while assigning unique / nonunique probabilities. To be used on original column
def unique_assignment(val, column):
    value = column[column.index == val]
    return value.iloc[0]

# %% [markdown]
# ## Putting Together Categorical Approach

# %%
# Obtains a date time object and treats this as numerical rather than categorical value
def obtainCatSurprise(table):
    cols = identifyCategorical(table)
    for col in cols:
        # Obtaining individual relative entropies, averaging them out, finding their p-values and calculating final surprise
        values = table.get(col)
        temp = (uniques(values)+special_char(values)+ nans(values) + types(values)+lenCount(values))/5
        table[col] = -np.log2(retPVal(temp))
    table = table.replace({np.nan:0})    
    return table

# %%
# For potential alias issues
def getCopy(table):
    return copy.copy(table)

# %% [markdown]
# # Date/Time

# %% [markdown]
# The issue of date times is quite an interesting one, as it cannot truly be treated as a categorical value (it's format holds little significance). Approaching it as a number is far more interesting, as the magnitude of a day, or rather the magnitude of the interval between the ordered days, may be indicative of an outlier.
#
# For example: a police call 40 years into the future could perhaps be considered a very troublesome value given the other most recent police call in the dataset was yesterday. The section below uses Kernel Density, just as seen above with numerical values, to treat the date intervals by **magnitude**

# %%
# Calculation of date time entropies
def dateTimeClassifier(column):
    # Conversion to proper format
    if (type(column.iloc[0]) == str):
        column = convert_to_dateTime(column)
        
    # Unix timestamps for ease of calculation
    unixCol = column.apply(convertToUnix).to_numpy()
    
    # Finding time intervals
    difference_array = np.append(np.array([]), np.diff(unixCol))
    timeFrame = (pd.DataFrame().assign(index = np.arange(1,len(unixCol)), Times_diff = difference_array))
    dateSurprise = surprise_Table(timeFrame, 'index')
    return (dateSurprise.sort_values(by = ['Times_diff'])).get('Times_diff')

# If date-value is given as a string, convert to date- time format first
def convert_to_dateTime(column):
    return pd.to_datetime(column, format='%Y%m%d %H:%M:%S')

        
# Converting the date to unix format for ease of calculations    
def convertToUnix(value):
    return (value - datetime(1970, 1, 1)).total_seconds()

# %% [markdown]
# # Mixed-Feature Correlation

# %% [markdown]
# Thus far Likelihood has adressed the issue of categorical values and numerical values mostly in separation, never truly combining the 2 together. This if a fine approach and quite effective in many contexts, but ignores a potential intrinsic correlation of categorical and numerical columns in the data. For example, in weather data the categorical value of location may be correlated with the value of temperature.
#
# These correlations could fall in 3 unadressed categories:
#
# 1) Correlation between different **categorical** values
#
# 2) Correlation between **categorical and numerical** values
#
# 3) Correlation between different **numerical** values.
#
# Since number 3 has already been tackled with the **Kernel Density-PCA**, so the remaining blind spot in Likelihood is in approaching the other 2:
#
# It seems that potentially, if we treat both as categorical data, we can accomplish both at once. The approach from this will be taken from Claude Shannon's *Mathematical Theory of Communications*, utilizing the idea of a third order categorical approximation (using three columns that add the most meaningful information) in order to properly predict the value of a categorical column.
#
# These will likely be the last anomaly computation methods in Likelihood. The next pressing issues seem to be releasing it and making it a scalable resource.

# %%
from sklearn import tree
from scipy.stats import percentileofscore
def fit_to_tree(column1, column2):
    classifier = tree.DecisionTreeClassifier()
    classifier = classifier.fit(np.reshape(column2,(-1,1)), column2)
    return classifier

# %%
# Finds the most chaotic combinations (meaning we actually have distribution on our hands) and returns them as array
# To be used for naive Bayes model
def obtainCombos(frame, column): 
    counts = []
    for x in frame.columns:
        val = frame.groupby(x).count().shape[0]
        counts.append(val)
    countVals = pd.Series(data = counts, index = frame.columns)
    
    # Only returning three columns we can most likely make a distribution off of, so that we can introduce variability and calculate strange Likelihoods
    # So as to find intermidiate values
    midpoint = int(len(countVals)/2)
    top3 = countVals.sort_values(ascending = True).iloc[midpoint-1: midpoint+1]
    return top3

# Categorical only DataFrame to be used later for proccessing purposes
def returnCategoricalFrame(frame):
    cols = identifyCategorical(frame)
    return (frame[cols]).reset_index()

# Changing numerical columns to behave as categorical columns for purpose of predicting categorical columns
def modifyNumerics(frame, categorical_columns, test_column):
    numericColumns = frame.select_dtypes(include = [np.number])
    numericColumns = numericColumns[numericColumns != test_column]
    for col in numericColumns:
        frame[col] = frame[col].apply(convertToPercentile, args = ([frame[col].to_numpy()]))
        frame[col] = frame[col].apply(place_in_numbin)
    return frame

# Converts individual values to percentiles
def convertToPercentile(val, values):
    return percentileofscore(values, val)


# Places numeric values in separate individual quartiles
def place_in_numbin(val):
    # Returning the quartile in which the number belongs
    if(isNan(val)):
        return 0
    else:
        return int(val/10)


# A simple counts-based probability distribution
def zeroOrderApprox(table, column):
    table = table.replace({np.nan:0})
    totalRows = table.shape[0]
    counts = table.groupby(column).count()
    otherCol = table.columns[0]
    return counts[otherCol] / totalRows

# Yields a Bayesian distribution using the context provided by another column, builds upon zeroOrder in complexity
def firstOrderApprox(table, column, other):
    
    # Ensuring that NaN values do not mess up value counts
    table = table.replace({np.nan:0})
    
    totalRows = table.shape[0]
    
    # Finding unique combinations to calculate P(B|A)
    counts = table.groupby([column,other]).count()
    otherCol = table.columns[0]
    
    # Calculating initial probabilities for A and B 
    initialA = zeroOrderApprox(table,column)
    initialB = zeroOrderApprox(table,other)
    
    #P(B|A)
    conditionalBGivenA = (counts[otherCol] / totalRows)
    updatedProb = conditionalBGivenA.multiply(initialA).reset_index().set_index(other)
    # Utilizing probability and given knowledge to yield an expected probability
    finalProb = pd.DataFrame().assign(data_value = updatedProb.get(column), given_knowledge = updatedProb.index,probability = updatedProb[otherCol].divide(initialB).values)
    return finalProb.set_index("data_value")

# Builds upon a first order approximation to add even 
def secondOrderApprox(table, column, other1,other2):
    
    # Ensuring that NaN values do not mess up value counts
    table = table.replace({np.nan:0})
    
    totalRows = table.shape[0]
    
    # Finding unique combinations to calculate P(B|A)
    counts = table.groupby([column,other1, other2]).count()
    otherCol = table.columns[0]
    initialC = zeroOrderApprox(table, other2)
    initialMutual = firstOrderApprox(table, column, other1)
    initialMutual = initialMutual.set_index("given_knowledge", append = True)
    return initialMutual
    
    
# Builds a model to obtain context and create a first order surprise approximation for a given column
def surpriseApprox(table, column):
    table = modifyNumerics(table, returnCategoricalFrame(table).columns,column)
    candidates = obtainCombos(table, column).index
    print(candidates)
    new_probs = firstOrderApprox(trainDf, column, candidates[1])
    new_probs = new_probs.assign(surprise = surprise(retPVal(new_probs.get("probability"))))
    new_probs = new_probs.sort_values(by = "surprise", ascending = False)
    return new_probs
secondOrderApprox(getCopy(trainDf), "day_of_week", "address_number_primary", "beat")
# Out:
#                             probability
# data_value given_knowledge
# 1          0                   0.016903
#            10                  0.019925
#            20                  0.017876
#            30                  0.021330
#            40                  0.022279
#            50                  0.024312
#            60                  0.020559
#            70                  0.012219
#            80                  0.016666
#            100                 0.012341
#            200                 0.023206
#            300                 0.025824
#            400                 0.024561
#            500                 0.029128
#            600                 0.016542
#            700                 0.019339
#            800                 0.018226
#            900                 0.011338
#            1000                0.031393
#            1100                0.022800
#            1200                0.023400
#            1300                0.017892
#            1400                0.016734
#            1500                0.023657
#            1600                0.012877
#            1700                0.017286
#            1800                0.030210
#            1900                0.023623
#            2000                0.019269
#            2100                0.022526
# ...                                 ...
# 7          15900               0.042923
#            16000               0.021608
#            16100               0.019686
#            16200               0.151256
#            16300               0.017892
#            16400               0.020917
#            16500               0.019714
#            16600               0.021608
#            16700               0.021579
#            16800               0.039371
#            16900               0.137997
#            17000               0.050077
#            17100               0.091866
#            17200               0.137800
#            17300               0.048807
#            17400               0.045999
#            17500               0.050419
#            17600               0.137997
#            17800               0.151051
#            17900               0.137997
#            18000               0.146420
#            18100               0.137997
#            18300               0.151051
#            18500               0.031312
#            18600               0.012202
#            18700               0.011500
#            18900               0.050077
#            19200               0.025175
#            19400               0.011483
#            34800               0.146420
#
# [1364 rows x 1 columns]

# %%
trainDf.groupby(["address_number_primary", "address_sfx_primary", "day_of_week"]).count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d319fca188cf> in <module>
# ----> 1 trainDf.groupby(["address_number_primary", "address_sfx_primary", "day_of_week"]).count()
#
# NameError: name 'trainDf' is not defined

# %% [markdown]
# # The Anomaly Report

# %% [markdown]
# This report will give the user a detailed picture of: is something wrong with their data, where is it, and hopefully why that is

# %%
# Assigning colors to problematic values (still grouped with indices so easy to tell)
# Yellow: mild concern, Orange: serious concern, red - major concern
def designer(frame):
    threshold1 = 5
    threshold2 = 20
    threshold3 = 40
    print("Would you like to reset default issue alert thresholds?")
    if(input().upper() == 'YES'):
        print("Mild concern threshold (in probability (percentage) of issue being present):")
        threshold1 = float(input())
        print("Moderate concern threshold (in probability (percentage) of issue being present)")
        threshold2 = float(input())
        print("Serious concern threshold (in probability (percentage) of issue being present)")
        threshold3 = float(input())
    temp = pcaPrep(frame)
    styler = frame.style
    for col in temp.columns:
        frame = styler.applymap(lambda x: 'background-color: %s' % 'yellow' if x > threshold1 else 'background-color: %s' % 'light-gray', subset = [col])
        frame = styler.applymap(lambda x: 'background-color: %s' % 'orange' if x > threshold2 else 'background-color: %s' % 'light-gray', subset = [col])
        frame = styler.applymap(lambda x: 'background-color: %s' % 'red' if x > threshold3 else 'background-color: %s' % 'light-gray', subset = [col])
    return frame 
       
designer(surpriseTable)
# Out:
# Would you like to reset default issue alert thresholds?
# no
# <style  type="text/css" >
#     #T_5c726db6_c074_11ea_8d44_8218532a6f00row0_col4 {
#             background-color:  light-gray;
#             background-color:  light-gray;
#             background-color:  light-gray;
#         }    #T_5c726db6_c074_11ea_8d44_8218532a6f00row0_col5 {
#             background-color:  light-gray;
#             background-color:  light-gray;
#             background-color:  light-gray;
#         }    #T_5c726db6_c074_11ea_8d44_8218532a6f00row0_col6 {
#             background-color:  yellow;
#             background-color:  light-gray;
#             background-color:  light-gray;
#         }    #T_5c726db6_c074_11ea_8d44_8218532a6f00row0_col7 {
#             background-color:  light-gray;
#             background-color:  light-gray;
#             background-color:  light-gray;
#         }    #T_5c726db6_c074_11ea_8d44_8218532a6f00row0_col8 {
#             background-color:  light-gray;
#             background-color:  light-gray;
#             background-color:  light-gray;
#         }    #T_5c726db6_c074_11ea_8d44_8218532a6f00row0_col9 {
#             background-color:  light-gray;
#             background-color:  light-gray;
#             background-color:  light-gray;
#         }    #T_5c726db6_c074_11ea_8d44_8218532a6f00row0_col10 {
#             background-color:  light-gray;
#             background-color:  light-gray;
#             background-color:  light-gray;
#         }    #T_5c726db6_c074_11ea_8d44_8218532a6f00row0_col11 {
#             background-color:  light-gray;
#             background-color:  light-gray;
#             background-color:  light-gray;
#         }    #T_5c726db6_c074_11ea_8d44_8218532a6f00row0_col12 {
#             background-color:  light-gray;
#             background-color:  light-gray;
#             background-color:  light-gray;
#         }    #T_5c726db6_c074_11ea_8d44_8218532a6f00row0_col13 {
#             background-color:  light-gray;
#             background-color:  light-gray;
#             background-color:  light-gray;
#         }    #T_5c726db6_c074_11ea_8d44_8218532a6f00row0_col14 {
#             background-color:  light-gray;
#             background-color:  light-gray;
#             background-color:  light-gray;
#         }    #T_5c726db6_c074_11ea_8d44_8218532a6f00row0_col15 {
#             background-color:  light-gray;
#             background-color:  light-gray;
#             background-color:  light-gray;
#         }    #T_5c726db6_c074_11ea_8d44_8218532a6f00row0_col16 {
#             background-color:  light-gray;
#             background-color:  light-gray;
#             background-color:  light-gray;
#         }    #T_5c726db6_c074_11ea_8d44_8218532a6f00row0_col17 {
#             background-color:  light-gray;
#             background-color:  light-gray;
#             background-color:  light-gray;
#         }    #T_5c726db6_c074_11ea_8d44_8218532a6f00row0_col18 {
#             background-color:  light-gray;
#             background-color:  light-gray;
#             background-color:  light-gray;
#         }    #T_5c726db6_c074_11ea_8d44_8218532a6f00row0_col19 {
#             background-color:  light-gray;
#             background-color:  light-gray;
#             background-color:  light-gray;
#         }    #T_5c726db6_c074_11ea_8d44_8218532a6f00row0_col20 {
#             background-color:  light-gray;
#             background-color:  light-gray;
#             background-color:  light-gray;
#         }    #T_5c726db6_c074_11ea_8d44_8218532a6f00row0_col21 {
#             background-color:  light-gray;
#             background-color:  light-gray;
#             background-color:  light-gray;
#         }    #T_5c726db6_c074_11ea_8d44_8218532a6f00row0_col22 {
#             background-color:  light-gray;
#             background-color:  light-gray;
#             background-color:  light-gray;
#         }    #T_5c726db6_c074_11ea_8d44_8218532a6f00row0_col24 {
#             background-color:  light-gray;
#             background-color:  light-gray;
#             background-color:  light-gray;
#         }    #T_5c726db6_c074_11ea_8d44_8218532a6f00row1_col4 {
#             background-color:  light-gray;
#             background-color:  light-gray;
#             background-color:  light-gray;
#         }    #T_5c726db6_c074_11ea_8d44_8218532a6f00row1_col5 {
#             background-color:  light-gray;
#             background-color:  light-gray;
#             background-color:  light-gray;
#         }    #T_5c726db6_c074_11ea_8d44_8218532a6f00row1_col6 {
#             background-color:  light-gray;
#             background-color:  light-gray;
#             background-color:  light-gray;
#         }    #T_5c726db6_c074_11ea_8d44_8218532a6f00row1_col7 {
#             background-color:  light-gray;
#             background-color:  light-gray;
#             background-color:  light-gray;
#         }    #T_5c726db6_c074_11ea_8d44_8218532a6f00row1_col8 {
#             background-color:  light-gray;
#             background-color:  light-gray;
#             background-color:  light-gray;
#         }    #T_5c726db6_c074_11ea_8d44_8218532a6f00row1_col9 {
#             background-color:  light-gray;
#             background-color:  light-gray;
#             background-color:  light-gray;
#         }    #T_5c726db6_c074_11ea_8d44_8218532a6f00row1_col10 {
#             background-color:  light-gray;
#             background-color:  light-gray;
#             background-color:  light-gray;
#         }    #T_5c726db6_c074_11ea_8d44_8218532a6f00row1_col11 {
#             background-color:  light-gray;
#             background-color:  light-gray;
#             background-color:  light-gray;
#         }    #T_5c726db6_c074_11ea_8d44_8218532a6f00row1_col12 {
#             background-color:  light-gray;
#             background-color:  light-gray;
#             background-color:  light-gray;
#         }    #T_5c726db6_c074_11ea_8d44_8218532a6f00row1_col13 {
#             background-color:  light-gray;
#             background-color:  light-gray;
#             background-color:  light-gray;
#         }    #T_5c726db6_c074_11ea_8d44_8218532a6f00row1_col14 {
#             background-color:  light-gray;
#             background-color:  light-gray;
#             background-color:  light-gray;
#         }    #T_5c726db6_c074_11ea_8d44_8218532a6f00row1_col15 {
#             background-color:  light-gray;
#             background-color:  light-gray;
#             background-color:  light-gray;
#         }    #T_5c726db6_c074_11ea_8d44_8218532a6f00row1_col16 {
#             background-color:  light-gray;
#             background-color:  light-gray;
#             background-color:  light-gray;
#         }    #T_5c726db6_c074_11ea_8d44_8218532a6f00row1_col17 {
#             background-color:  light-gray;
#             background-color:  light-gray;
#             background-color:  light-gray;
#         }    #T_5c726db6_c074_11ea_8d44_8218532a6f00row1_col18 {
#             background-color:  yellow;
#             background-color:  light-gray;
#             background-color:  light-gray;
#         }    #T_5c726db6_c074_11ea_8d44_8218532a6f00row1_col19 {
#             background-color:  light-gray;
#             background-color:  light-gray;
#             background-color:  light-gray;
#         }    #T_5c726db6_c074_11ea_8d44_8218532a6f00row1_col20 {
#             background-color:  light-gray;
#             background-color:  light-gray;
#             background-color:  light-gray;
#         }    #T_5c726db6_c074_11ea_8d44_8218532a6f00row1_col21 {
#             background-color:  light-gray;
#             background-color:  light-gray;
#             background-color:  light-gray;
#         }    #T_5c726db6_c074_11ea_8d44_8218532a6f00row1_col22 {
#             background-color:  light-gray;
#             background-color:  light-gray;
#             background-color:  light-gray;
#         }    #T_5c726db6_c074_11ea_8d44_8218532a6f00row1_col24 {
#             background-color:  light-gray;
#             background-color:  light-gray;
#             background-color:  light-gray;
#         }    #T_5c726db6_c074_11ea_8d44_8218532a6f00row2_col4 {
#             background-color:  light-gray;
#             background-color:  light-gray;
#             background-color:  light-gray;
#         }    #T_5c726db6_c074_11ea_8d44_8218532a6f
